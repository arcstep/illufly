# %%
# %pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /Users/xuehongwei/Library/Caches/pypoetry/virtualenvs/langchain-book-u1j6yauo-py3.10/lib/python3.10/site-packages (from python-docx) (5.2.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in /Users/xuehongwei/Library/Caches/pypoetry/virtualenvs/langchain-book-u1j6yauo-py3.10/lib/python3.10/site-packages (from python-docx) (4.11.0)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 407.5 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)

import os
os.chdir('..')

# %%
from illufly.config import get_ILLUFLY_doc
import os
filename = get_ILLUFLY_doc("Case_YC/Q : JXZY-JG206 003-2023相关方管理规定.docx")
os.path.exists(filename)
# Out:
# True

# %%
from docx import Document

def print_headings(doc_path):
    doc = Document(doc_path)
    for paragraph in doc.paragraphs:
        print("<< STYLE:", paragraph.style.name, ">>")
        # if paragraph.style.name.startswith('Heading'):
        print(paragraph.text)

print_headings(filename)
# Out:
# << STYLE: 其他标准标志 >>
# Q/JXZY
# << STYLE: 其他标准称谓 >>
# 江西中烟工业有限责任公司企业标准
# << STYLE: 封面标准号2 >>
# Q/JXZY-JG 206 003—2023
# << STYLE: 封面标准号2 >>
#
# << STYLE: 封面标准名称 >>
# 相关方管理规定
# << STYLE: 封面标准英文名称 >>
#
# << STYLE: 封面一致性程度标识 >>
#
# << STYLE: 其他发布日期 >>
# 2023- 06- 30发布
# << STYLE: 其他实施日期 >>
# 2023 - 06 - 30实施
# << STYLE: 其他发布部门 >>
# 井冈山卷烟厂   发布
# << STYLE: 段 >>
#
# << STYLE: 目次、标准名称标题 >>
# 目  次
# << STYLE: toc 1 >>
# 前言	II
# << STYLE: toc 1 >>
# 1　范围	1
# << STYLE: toc 1 >>
# 2　规范性引用文件	1
# << STYLE: toc 1 >>
# 3　术语和定义	1
# << STYLE: toc 3 >>
# 3.1　产品供方	1
# << STYLE: toc 3 >>
# 3.2　服务供方	1
# << STYLE: toc 1 >>
# 4　职责与权限	1
# << STYLE: toc 3 >>
# 4.1　安全管理科	1
# << STYLE: toc 3 >>
# 4.2　企业管理科	2
# << STYLE: toc 3 >>
# 4.3　各部门	2
# << STYLE: toc 1 >>
# 5　工作程序及要求	2
# << STYLE: toc 3 >>
# 5.1　相关方及相关方需求	2
# << STYLE: toc 3 >>
# 5.2　一般相关方管理	2
# << STYLE: toc 3 >>
# 5.3　重点相关方管理	3
# << STYLE: toc 1 >>
# 6　相关记录	5
# << STYLE: toc 3 >>
# 6.1　相关方需求一览表	5
# << STYLE: toc 3 >>
# 6.2　相关方告知与技术交底	5
# << STYLE: toc 3 >>
# 6.3　安全环保协议	5
# << STYLE: toc 3 >>
# 6.4　重点相关方管理台账	5
# << STYLE: toc 3 >>
# 6.5　重点相关方绩效评价表	5
# << STYLE: toc 3 >>
# 6.6　来访人员接洽单	5
# << STYLE: toc 1 >>
# 附录A（规范性附录）　相关方管理流程图	6
# << STYLE: toc 3 >>
# A.1　相关方管理流程图	6
# << STYLE: toc 1 >>
# 附录B（规范性附录）　相关方管理记录	7
# << STYLE: toc 3 >>
# B.1　重点相关方安全技术交底	7
# << STYLE: toc 3 >>
# B.2　安全环保协议	10
# << STYLE: toc 3 >>
# B.3　重点相关方管理台账	1
# << STYLE: toc 3 >>
# B.4　重点相关方绩效评价表	2
# << STYLE: toc 3 >>
# B.5　来访人员接洽单	3
# << STYLE: 段 >>
#
# << STYLE: 前言、引言标题 >>
# 前  言
# << STYLE: 段 >>
# 本标准代替Q/JXZY-JG 206 003-2018《相关方控制程序》。本标准修改的主要内容有：
# << STYLE: 段 >>
# ——安全管理科职责；
# << STYLE: 段 >>
# ——一般相关方管理；
# << STYLE: 段 >>
# ——重点相关方管理；
# << STYLE: 段 >>
# ——安全环保协议。
# << STYLE: 段 >>
# 本标准依据YC/T 384－2018《烟草企业安全生产标准化规范》、ISO/14001-2015《环境管理体系 要求及使用指南》、GB/T45001-2020 《职业健康安全管理体系要求及使用指南》及GB/T19001《质量管理体系 要求》，结合井冈山卷烟厂的管理特点，明确了相关方识别、相关方要求、绩效评价、监督与检查的要求。
# << STYLE: 段 >>
# 本标准依据GB/T1.1-2020标准化工作导则 第1部分 标准化文件的结构和起草规则。
# << STYLE: 段 >>
# 本标准由井冈山卷烟厂标准化技术委员分会提出。
# << STYLE: 段 >>
# 本标准由井冈山卷烟厂管理标准专业工作组归口管理。
# << STYLE: 段 >>
# 本标准起草部门：安全管理科。
# << STYLE: 段 >>
# 本标准的主要起草人：陈海晶。
# << STYLE: 段 >>
# 本标准参与评审人员：陶志钢 郭铁松 刘凌 李丽 彭婉琳 曾嘉豪。
# << STYLE: 段 >>
# 本标准审核人：辜志茂。
# << STYLE: 段 >>
# 本标准批准人：刘世文。
# << STYLE: 段 >>
# 本标准是第四次发布。本标准历次发布版本是：
# << STYLE: 段 >>
# ——Q/JXZY-JG 206 003-2011；
# << STYLE: 段 >>
# ——Q/JXZY-JG 206 003-2015；
# << STYLE: 段 >>
# ——Q/JXZY-JG 206 003-2018。
# << STYLE: 目次、标准名称标题 >>
# 相关方管理规定
# << STYLE: 章标题 >>
# 范围
# << STYLE: Normal >>
# 本标准规定了相关方识别、相关方要求、绩效评价、监督与检查的要求。
# << STYLE: Normal >>
# 本标准适用于与企业质量、环境和职业健康安全有关的相关方的管理。
# << STYLE: 章标题 >>
# 规范性引用文件
# << STYLE: Normal >>
# 下列文件对于本文件的应用是必不可少的。凡是注日期的引用文件，仅所注日期的版本适用于本文件。凡是不注日期的引用文件，其最新版本（包括所有的修改单）适用于本文件。
# << STYLE: Normal >>
# YC/T 384-2018《烟草企业安全生产标准化规范》
# << STYLE: Normal >>
# ISO/14001-2015《环境管理体系  要求及使用指南》
# << STYLE: Normal >>
# GB/T45001-2020《职业健康安全管理体系 要求及使用指南》
# << STYLE: Normal >>
# GB/T19001-2016《质量管理体系 要求》
# << STYLE: Normal >>
# Q/JXZY-JG 206 001《危险源辨识、风险评价和风险控制程序》
# << STYLE: Normal >>
# Q/JXZY-JG 207 001《信息交流与协商控制程序》
# << STYLE: Normal >>
# Q/JXZY-JG 212 005《改进控制程序》
# << STYLE: 章标题 >>
# 术语和定义
# << STYLE: Normal >>
# GB/T45001《职业健康安全管理体系  要求》、ISO/14001《环境管理体系  要求及使用指南》以及下列术语和定义适用于本标准。
# << STYLE: 一级条标题 >>
# 产品供方
# << STYLE: Normal >>
# 为企业提供原、辅材料、设备、备品备件、油料、化学品等物资的组织。
# << STYLE: 一级条标题 >>
# 服务供方
# << STYLE: Normal >>
# 为企业提供建筑施工和拆除、房屋修缮和装修装潢，设备设施安装拆除和维修保养、食堂运行、绿化保洁、外墙清洗、磷化铝杀虫、物流运输、保安服务、消防服务、物业服务、顾客、最终用户或受益人、法律法规及监管机关、员工及为　企业工作的人员、周边企业及社区居民、进入　企业内的其他人员等人员或组织。
# << STYLE: 章标题 >>
# 职责与权限
# << STYLE: 一级条标题 >>
# 安全管理科
# << STYLE: 二级无 >>
# 负责相关方在职业健康安全管理及环境管理体系方面有关的管理。
# << STYLE: 二级无 >>
# 负责监视和评价相关方在职业健康安全及环境管理管理体系方面有关的信息及要求。
# << STYLE: 一级条标题 >>
# 企业管理科
# << STYLE: 二级无 >>
# 负责相关方在质量管理体系方面有关的管理。
# << STYLE: 二级无 >>
# 负责监视和评价相关方在质量管理体系方面有关的信息及要求。
# << STYLE: 一级条标题 >>
# 各部门
# << STYLE: 二级无 >>
# 负责与本部门业务有关的重点相关方的管理及现场安全风险的告知。
# << STYLE: 二级无 >>
# 负责监视和评价与本部门业务有关相关方的信息及要求。
# << STYLE: 章标题 >>
# 工作程序及要求
# << STYLE: 一级条标题 >>
# 相关方及相关方需求
# << STYLE: 二级无 >>
# 相关方识别
# << STYLE: 三级无 >>
# 各职能管理部门及各部门按“谁用工、谁负责”的原则,对其业务活动有关的相关方进行识别和确定。
# << STYLE: 三级无 >>
# 在识别确定相关方时通常包括：
# << STYLE: Normal >>
# 企业员工；
# << STYLE: Normal >>
# 重点相关方：如：工程项目施工方、设备设施维修保养方、绿化保洁、物业服务方、食堂供应方、物流运输方、杀虫相关方、污水处理作业方、外墙清洗作业方、危化品供应方、保安、消防服务方、生产性业务外包方、其他现场施工作业方；
# << STYLE: Normal >>
# 一般相关方：如：政府机构、法律法规及监管机关、顾客、除重点相关方外的其他外部供方、周边企业及社区居民、进入企业内的其他非现场施工作业方人员。
# << STYLE: 二级无 >>
# 相关方需求确定
# << STYLE: 三级无 >>
# 各职能管理部门及各部门通过沟通、调查、调研等方法确定对相关方的要求。
# << STYLE: 三级无 >>
# 在确定对相关方需求时通常包括：
# << STYLE: Normal >>
# 顾客对产品或服务的要求，如符合性、安全性、环保性等；
# << STYLE: Normal >>
# ——法律法规要求或行业规范及标准要求；
# << STYLE: Normal >>
# ——许可，执照或其它授权要求；
# << STYLE: Normal >>
# ——和公共机构及顾客的协议；
# << STYLE: Normal >>
# ——已与顾客或外部供应商达成的合同及合同的承担义务；
# << STYLE: Normal >>
# 社区居民要求；
# << STYLE: Normal >>
# 其他要求。
# << STYLE: 二级无 >>
# 监视和评审
# << STYLE: 三级无 >>
# 各部门对重点相关方按5.3条款的要求进行监视和评价。
# << STYLE: 一级条标题 >>
# 一般相关方管理
# << STYLE: 二级无 >>
# 相关方人员进入生产现场、库区等区域应由业务部门安排人员陪同；
# << STYLE: Normal >>
# 外来人员进厂，门岗进行扫访客和车辆进出登记二维码登记工作，由门岗值班人员进行相关方告知。
# << STYLE: 二级无 >>
# 指导检查及参观人员
# << STYLE: 三级无 >>
# 由相关部门告知进入厂区的职业健康安全、环境、质量管理方面的有关要求，并由一人扫访客和车辆进出登记二维码；
# << STYLE: 三级无 >>
# 在门岗登记《来访人员接洽单》（附录B5）并由门岗值班人员进行相关方告知。
# << STYLE: 二级无 >>
# 来厂联系业务人员
# << STYLE: 三级无 >>
# 进入厂区应办理身份确认和登记手续，并扫访客和车辆进出登记二维码；
# << STYLE: 三级无 >>
# 在门岗登记《来访人员接洽单》（附录B5）并由门岗值班人员进行相关方告知。
# << STYLE: 二级无 >>
# 其他一般相关方
# << STYLE: 三级无 >>
# 除上述人员以外的来厂人员，都属于其他一般相关方；
# << STYLE: 三级无 >>
# 进入厂区应办理身份确认和登记手续，并扫访客和车辆进出登记二维码；
# << STYLE: 三级无 >>
# 在门岗登记《来访人员接洽单》（附录B5）并由门岗值班人员进行相关方告知。
# << STYLE: 一级条标题 >>
# 重点相关方管理
# << STYLE: 二级无 >>
# 外来人员进厂，门岗进行扫二维码登记工作，由门岗值班人员进行相关方告知。
# << STYLE: 二级无 >>
# 资质要求
# << STYLE: 三级无 >>
# 业务部门通常以沟通、询问、调查的方式获取相关方的基本信息；
# << STYLE: 三级无 >>
# 业务部门对相关方单位的营业执照、相应的许可证、人员资质等进行审查，符合国家和地方法律法规要求并具备相应安全生产条件的方可选择为产品供方或服务供方；
# << STYLE: 三级无 >>
# 业务部门收集并保存相关方资质资料。
# << STYLE: 二级无 >>
# 人员管理
# << STYLE: 三级无 >>
# 相关方人员进入厂区，应办理身份确认和登记手续；
# << STYLE: 三级无 >>
# 相关方人员进入生产现场、库区等区域，应由业务部门安排人员陪同；
# << STYLE: 三级无 >>
# 长期内出入企业的相关方人员等，应办理出入证，人员离开后，应回收出入证，并建立出入证发放回收台账。
# << STYLE: 二级无 >>
# 告知和交底
# << STYLE: 三级无 >>
# 相关方人员初次进入厂区时，各职能管理部门及业务部门应告知进入厂区的职业健康安全、环境、质量管理方面的有关要求，并在《重点相关方安全技术交底》（附录B1）上签字确认。
# << STYLE: 三级无 >>
# 相关方人员在一个服务期内首次进场作业前，业务作业归口管理部门、属地管理部门应共同组织对相关方项目负责人和安全员进行技术交底，相关方人员在接受交底后在《重点相关方安全技术交底》上签字确认，相关方项目负责人对作业人员进行培训。
# << STYLE: 三级无 >>
# 服务期超过一年的至少每年进行一次再交底，相关方活动和人员发生较大变化的，也应组织再交底，交底记录报相关职能管理部门备案。
# << STYLE: 三级无 >>
# 技术交底包括：
# << STYLE: Normal >>
# 作业过程主要风险及其控制要求；
# << STYLE: Normal >>
# 相关方需执行的本单位相关安全规章制度、应急预案或应急措施；
# << STYLE: Normal >>
# 相关方的隐患排查治理要求；
# << STYLE: Normal >>
# 对质量、环境影响因素等。
# << STYLE: 二级无 >>
# 安全环保协议
# << STYLE: 三级无 >>
# 重点相关方及长期在单位从事零星项目施工或服务的应签订《安全环保协议》（附录B2），安全环保协议一式三份，施工方、对口管理部门、安全管理科各执一份；
# << STYLE: 三级无 >>
# 安全环保协议内，依据风险特点和风险程度，明确双方的安全管理职责、人员管理、设备管理、作业管理、原辅材料管理、风险管控和隐患排查治理、违章和事故处置、相应的违约责任追究、考核和合同终止条款等个性化内容，并要求在企业现场工作的重点相关方配备专职或兼职安全员；
# << STYLE: 三级无 >>
# 签订安全环保协议前，各部门应组织相关方按《危险源辨识、风险评价和风险控制程序》及《环境因素识别与评价控制程序》对相关方服务进行风险辨识和评价、确定风险控制措施，形成风险控制清单，相关方才能进行施工，清单应作为安全环保协议的附件；
# << STYLE: 三级无 >>
# 单项项目的安全环保协议有效期为一个施工或服务周期；长期在单位从事零星项目施工或服务的承包方，安全环保协议有效期可与合同期一致，但不得超过三年，宜一年一签；
# << STYLE: 三级无 >>
# 相关方设备设施、作业活动、人员有较大变化时，应重新签订安全环保协议及重新进行风险辨识、评价和确定控制措施；
# << STYLE: 三级无 >>
# 各部门实施高处作业、动火作业等危险作业时应按《危险作业管理规定》中明确的要求执行。
# << STYLE: 二级无 >>
# 信息管理
# << STYLE: 三级无 >>
# 各部门对识别和确定的提供活动、服务和产品相关方进行管理，建立《重点相关方管理台账》（附录B3），并在《重点相关方管理台账》中登记相关方信息和主管部门；重点相关方在属地管理部门长期作业的，属地管理部门应建立《重点相关方管理台账》；
# << STYLE: 三级无 >>
# 各部门每年年初将《重点相关方管理台账》提交到安全管理科备案存档。
# << STYLE: 二级无 >>
# 绩效评价
# << STYLE: 三级无 >>
# 安全管理科组织重点相关方归口管理部门对重点相关方每年进行一次职业健康安全及环境影响绩效评价，形成《重点相关方绩效评价表》（附录B4）；
# << STYLE: 三级无 >>
# 评价时由业务作业归口管理部门、属地管理部门、各职能管理部门参加，依据日常监督检查的结果对其资质、相关制度和要求的执行情况、设备设施和作业活动的风险控制措施有效性、隐患排查治理情况、未遂事件和事故发生情况等进行评价，并保存记录；
# << STYLE: 三级无 >>
# 相关方年度绩效评价结果，应作为下一年度或下一服务期选择相关方的依据；
# << STYLE: 三级无 >>
# 对评价中存在的问题要求其限期整改，整改后仍然不符合要求的，业务作业归口管理部门严格按照合同约定追究责任；
# << STYLE: 三级无 >>
# 对相关方的投诉或相关信息，各职能管理部门和相关部门按《信息交流与协商控制程序》协调处置。
# << STYLE: 二级无 >>
# 监督与检查
# << STYLE: 三级无 >>
# 各职能管理部门及相关部门对其施加职业健康安全、环境、质量控制影响，对部门的相关方进行监督管理；
# << STYLE: 三级无 >>
# 各部门对相关方作业场所及其设备设施、作业活动过程进行监督检查，并保存记录；
# << STYLE: 三级无 >>
# 对单项作业的相关方，作业期间至少监督检查一次；对超过一个月连续作业的相关方，监督检查每月不少于一次；
# << STYLE: 三级无 >>
# 属地管理部门应指定部门安全员或班组长等，对相关方作业进行现场监督，发现事故隐患立即制止，并要求其整改，无法解决的，立即报告相关方的归口管理部门和安保科解决，并保存相应的记录；
# << STYLE: 三级无 >>
# 安全管理科组织监督检查各部门对相关方管控情况，对检查发现的安全隐患和问题按《改进控制程序》实施改进。
# << STYLE: 二级无 >>
# 环境管理
# << STYLE: Normal >>
# 相关方进厂作业要注意企业的环境保护，作业留下的废弃物要及时清理，不得留在厂区。
# << STYLE: 二级无 >>
# 生产性业务外包
# << STYLE: 三级无 >>
# 职能部门在选择生产性业务外包相关方单位时，应审核营业执照的业务范围和人员资质证明，并将安全保障能力作为其重要的资信条件；其派出的承包团队应配置生产管理人员和安全员，防止变相成为被派遣劳动者；
# << STYLE: 三级无 >>
# 安全环保协议明确生产性业务外包相关方的主体责任，明确其使用本单位相关设备设施的日常检修和维保、职业危害日常监测和定期检测、职业健康监护体检等事项的责任和要求；
# << STYLE: 三级无 >>
# 相关方制定并实施安全规章制度，包括：安全生产责任制、上岗人员流动和换岗、培训管理、设备设施日常管理和维检修、危险作业管理、作业现场风险管控和隐患排查、事件事故报告和处理等，内容要符合本单位安全管理的相关要求，相关规章制度报职能部门备案审查；
# << STYLE: 三级无 >>
# 相关方编制岗位或设备设施的安全操作规程，报职能部门备案审查；使用本单位设备的，本单位提供安全操作规程；
# << STYLE: 三级无 >>
# 要求相关方对派遣人员进行安全教育培训、资质考核取证，并符合本单位管理制度的要求；其三级安全教育的教材和大纲，应报职能部门备案审查，或使用本单位规范的教材和大纲；
# << STYLE: 三级无 >>
# 相关方为现场作业人员配备劳动防护用品，配备标准按本单位配备标准执行；
# << STYLE: 三级无 >>
# 相关方执行本单位职业危害管理要求，职业病危害因素检测、监护体检及监护档案资料应报职能部门备案审查；
# << STYLE: 三级无 >>
# 要求相关方参加本单位和所在区域的应急预案演练；要求相关方编制相关岗位的应急处置卡，其中危险性较大的场所、装置或者设施应编制现场处置方案并组织演练；应急处置卡和相关预案报职能部门备案审查，演练记录报职能部门备案。
# << STYLE: 章标题 >>
# 相关记录
# << STYLE: 一级条标题 >>
# 相关方告知与技术交底
# << STYLE: 一级条标题 >>
# 安全环保协议
# << STYLE: 一级条标题 >>
# 重点相关方管理台账
# << STYLE: 一级条标题 >>
# 重点相关方绩效评价表
# << STYLE: 一级条标题 >>
# 来访人员接洽单
# << STYLE: 段 >>
#
# << STYLE: 附录图标号 >>
#
# << STYLE: 附录表标号 >>
#
# << STYLE: 附录标识 >>
#
# （规范性附录）
# 相关方管理流程图
# << STYLE: 附录章标题 >>
# 相关方管理流程图
# << STYLE: 段 >>
#
# << STYLE: 附录图标题 >>
# 相关方管理流程图
# << STYLE: 附录图标号 >>
#
# << STYLE: 附录表标号 >>
#
# << STYLE: 附录标识 >>
#
# （规范性附录）
# 相关方管理记录
# << STYLE: 附录章标题 >>
# 重点相关方安全技术交底
# << STYLE: 附录表标题 >>
# 重点相关方安全技术交底
# << STYLE: 段 >>
# 编号：
# << STYLE: 附录章标题 >>
# 安全环保协议
# << STYLE: 附录表标题 >>
# 安全环保协议
# << STYLE: 段 >>
# 编号：
# << STYLE: Normal >>
# 甲方（与合同称谓一致）：   江西中烟工业有限责任公司
# << STYLE: Normal >>
# 乙方（与合同称谓一致）：
# << STYLE: Normal >>
# 依照《中华人民共和国民法典》、《中华人民共和国安全生产法》、《中华人民共和国消防法》及其他相关法律、法规的要求，以及江西中烟工业有限责任公司职业健康安全管理相关规章制度的要求，甲乙双方经协商达成一致，签订本协议。甲乙双方均应自觉遵守国家的法律、法规，共同信守，严格履行。
# << STYLE: Normal >>
# 建设单位
# << STYLE: Normal >>
# 项目名称：
# << STYLE: Normal >>
# 施工或作业、服务地点：
# << STYLE: Normal >>
# 乙方资质及安全生产条件
# << STYLE: Normal >>
# 乙方的资质名称：
# << STYLE: Normal >>
# 乙方的安全生产条件：
# << STYLE: Normal >>
# 甲方职责
# << STYLE: Normal >>
# 严格遵守国家有关安全生产的法律法规，认真执行商务合同中的有关安全要求。
# << STYLE: Normal >>
# 按照“安全第一、预防为主、综合治理”的方针和坚持“谁主管、谁负责”的原则对项目施工及生产作业、服务进行安全监督管理，做到项目施工或生产、服务作业与安全工作同时计划、布置、检查、总结和评比。
# << STYLE: Normal >>
# 甲方应将合同履行涉及到的甲方安全管理制度和安全技术要求向乙方传递交底。
# << STYLE: Normal >>
# 甲方应向乙方告知施工（作业或服务）现场的状况及注意事项。
# << STYLE: Normal >>
# 甲方有权对乙方施工（作业或服务）现场及整个履约过程进行监督、检查，对检查中发现的安全隐患有权责令整改、停工整顿。
# << STYLE: Normal >>
# 非甲方原因造成的安全事故，甲方概不承担任何责任，但甲方应为抢救伤员等抢险救灾提供各种方便。
# << STYLE: Normal >>
# 乙方在服务过程中发生的设备、人身、环保事故，甲方有责任负责调查、统计上报。乙方在服务过程中如发生事故，事故类别达到《生产安全事故报告和调查处理实施条例》所规定的事故，甲方有权督促乙方立即通知当地政府和公安部门，要求派人保护现场；并有权要求乙方提供事故调查书面结论及处理意见。
# << STYLE: Normal >>
# 乙方职责
# << STYLE: Normal >>
# 乙方各级领导、工程技术人员、管理人员和具体操作人员，必须熟悉和遵守本条款的各项规定。
# << STYLE: Normal >>
# 坚持“安全第一、预防为主、综合治理”的方针和“谁主管、谁负责”的原则，乙方应建立健全各项安全生产的管理机构和安全生产管理制度，按要求配备专职或兼职安全人员，做到项目施工（维修）作业、服务与安全工作同时计划、布置、检查、总结和评比。
# << STYLE: Normal >>
# 乙方必须具有合法资质，将相关资料原件提交甲方审核，并对资料真实性负责，资料复印件交到甲方业务实施部门备案。
# << STYLE: Normal >>
# 乙方必须为在本项目服务的从业人员(以下简称从业人员)办理合法的用工手续；不得聘用公安机关追逃人员、邪教组织参与人员等违法犯罪人员；若聘用有违法犯罪记录人员的，乙方应报甲方安全管理部门备案。
# << STYLE: Normal >>
# 乙方应组织从业人员学习甲方的相关安全管理制度，并保留相关学习及安全管理记录；乙方必须严格按甲方相关安全管理制度组织项目施工、服务或生产作业，组织开展安全检查，并保留相关安全检查记录。
# << STYLE: Normal >>
# 乙方应组织从业人员进行安全技术教育、安全告知、安全技术交底，熟知和遵守各项安全技术操作规程，定期进行安全技术考核，合格者方可上岗操作；乙方在甲方单位从事电气、起重、建筑登高架设作业、锅炉压力容器、焊接、机动车驾驶、爆破等特殊工种的人员，必须经过专业培训，取得国家相关专业主管部门核发的特种作业或特种设备操作证后，方准持证上岗。
# << STYLE: Normal >>
# 乙方不得擅自将工程转包、分包和返包。
# << STYLE: Normal >>
# 乙方进入甲方区域作业前，必须按甲方相关安全管理制度办理出入证，并严格要求进入人员妥善保管好出入证，不得转借、涂改或使用假冒、失效的出入证；乙方人员应自觉接受甲方查验。
# << STYLE: Normal >>
# 乙方在施工（作业或服务）过程中不得擅自更换工程技术管理人员、安全管理人员以及关系到施工（作业或服务）安全及质量的特殊工种人员，特殊情况需要更换人员时须征得甲方的同意。
# << STYLE: Normal >>
# 乙方应严格遵守国家相关法律法规的要求，为乙方人员配备、发放符合国家标准和行业标准的劳动保护用品，督促已方人员正确穿戴使用劳动保护用品，并做好检查、记录工作。
# << STYLE: Normal >>
# 乙方在施工（作业或服务）区域行驶或停放的机动车辆应服从指挥，禁止在消防通道、道路交叉出入口以及设有禁停标识和未划有停车线位的区域停放，禁止超速行驶。
# << STYLE: Normal >>
# 针对不同的分项项目，乙方在开工（作业或服务）前必须进行安全技术交底，并与分项项目各班组签订安全协议，开展安全风险辨识及评价工作，制定有效的安全风险控制措施。
# << STYLE: Normal >>
# 乙方必须按照施工（作业或服务）项目的特点，组织制定安全事故应急救援预案并定期组织预案演练，保留相关记录。
# << STYLE: Normal >>
# 乙方在施工（作业或服务）过程中，需进行吊装、焊接氧割、明火、高处、有限空间、拆除等危险作业时应办理许可证，并严格按照审批许可要求实施。
# << STYLE: Normal >>
# 乙方进场施工（作业或服务）的设备、工具等必须符合安全要求；乙方应根据施工（作业或服务）现场实际情况,配置符合安全要求的各项安全防护和安全标识。
# << STYLE: Normal >>
# 乙方必须及时反馈所属项目施工（作业或服务）现场的各类安全异常情况或信息，并积极配合甲方协调和处理相关安全问题。
# << STYLE: Normal >>
# 乙方发生损坏甲方财产情形的，乙方应主动向甲方报告并协商修复或赔偿。
# << STYLE: Normal >>
# 乙方履约过程中发生安全事故，必须立即向甲方报告，并采取相应的措施保护好现场，按应急预案组织处置，同时按照安全生产事故“四不放过”的原则进行处理。
# << STYLE: Normal >>
# 乙方必须服从甲方的安全监督、检查，不得以任何理由、方式阻碍甲方履行安全监督职能。
# << STYLE: Normal >>
# 乙方人员只能在甲方规定的区域内实施作业或服务，未经许可擅自进入其他区域导致的安全事故事件后果概由乙方负责。
# << STYLE: Normal >>
# 乙方服务过程中发生人身伤亡、火灾、设备等事故或危及生产运行的不安全情况或环境影响，应立即报告甲方，保护事故现场，按照国家法律法规相关要求向事故所在地的政府应急管理部门、公安部门、工会报告，组织或配合有关部门调查，并将事故调查组的事故调查报告及乙方事故处理意见提交甲方备案。
# << STYLE: Normal >>
# 检查与考核
# << STYLE: Normal >>
# 经双方协商一致，乙方同意接受以下约束性条款，如有违反甲方相关安全管理制度情形的，甲方有权根据约束性条款的金额直接从乙方履约保证金中扣除，若未约定履约保证金，则可直接缴交现金，无现金缴交的由财务管理科直接从合同款中扣除。
# << STYLE: Normal >>
# 乙方因管理不善或安全风险控制措施不到位而发生重大以上安全责任事故或涉稳事件，严重影响甲方正常生产秩序或受到有关主管部门查处的，扣除全部履约保证金。
# << STYLE: Normal >>
# 乙方所申报的特种设备安全状况应符合国家法律、法规的相关要求。乙方所申报的特种设备与实际作业设备不符，每台次扣除500元，并重新更换设备或补办手续后方可使用；特种作业人员应持证上岗，作业人员无相关证件或人证不符，每人次扣除500元。
# << STYLE: Normal >>
# 乙方违章吸烟或在禁烟区域内发现烟头按每个烟头处罚1000元，情节严重的按治安管理处罚法移交送交司法机关处理。
# << STYLE: Normal >>
# 乙方在进行吊装、焊接氧割、明火、高处、有限空间、拆除等危险作业施工前应按甲方规定办理审批许可证，施工过程中应符合国家相关法律、法规要求，违章作业每次扣除100元，情节严重的按治安管理处罚法规定移交政府相关部门处理。
# << STYLE: Normal >>
# 临时用电未按规范要求实施的，每处扣除200元。
# << STYLE: Normal >>
# 因乙方原因造成的安全事故或未遂事件，扣除全部履约保证金，造成实际损失的，由乙方负责赔偿甲方经济损失，情节严重的送交司法机关处理。
# << STYLE: Normal >>
# 乙方人员违反甲方相关管理规定，私带或私藏卷烟及卷烟商标纸，不论品牌、目的及来源，按《江西中烟井冈山卷烟厂关于印发偷盗卷烟产品、卷烟原辅材料及其它物资的处理决定的通知》规定执行。
# << STYLE: Normal >>
# 乙方人员违反甲方有关安全、消防、治安、道路交通运输等规章制度的，按甲方有关规定处理；损坏甲方通讯、电力、消防设施及器材的，照价赔偿；易燃、易爆等危险物品未按规定分类存放或堆放不符合有关规定或无专人管理、私自携带违禁物品进入施工区域的每次处罚200元；设备带病运转或无安全防护装置的、下班后未及时切断施工设备电源的，每处处罚200元；乙方人员在甲方区域未正确穿戴使用劳动保护用品的每次处罚200元。
# << STYLE: Normal >>
# 乙方人员在甲方厂区内发生违法犯罪行为，被公安机关查处，受到行政处罚的，每人次处罚500元；构成犯罪的，每人次处罚2000元。
# << STYLE: Normal >>
# 乙方人员在甲方厂区内发生一般安全责任事故或群体性涉稳事件，视情况每起处罚1000元。
# << STYLE: Normal >>
# 乙方违反本协议造成重大安全事故的(包括对第三方造成的损失)，乙方应赔偿其经济损失；同时，扣除全部工程款。
# << STYLE: Normal >>
# 乙方违反本协议约定义务，甲方要求限期整改的，乙方应在指定期限内整改，整改不及时或达不到要求的，按本协议相应条款加倍扣款，本协议无相应扣款条款的，按每项次500元基标准加倍扣款；对违章情节较为严重的乙方人员，甲方有权要求乙方更换，乙方应当更换人员。
# << STYLE: Normal >>
# 乙方不得随意动用甲方厂区内的消防设施，清洗设备需要动用消防栓时，应提前向安全管理部门办理申报批准手续，违规使用消防设施的每次处罚 100元。
# << STYLE: Normal >>
# 乙方违反本协议造成重大安全事故的(包括对第三方造成的损失)，乙方应赔偿其经济损失；同时，扣除全部工程款。
# << STYLE: Normal >>
# 乙方违反本协议约定义务，甲方要求限期整改的，乙方应在指定期限内整改，整改不及时或达不到要求的，按本协议相应条款加倍扣除，本协议无相应扣除条款的，依据甲方《平安建设及安全管理考核方案》进行考核；对违章情节较为严重的乙方人员，甲方有权要求乙方更换人员。
# << STYLE: Normal >>
# 考核中有达到一次性扣除乙方全部工程款的，则甲方有权暂停乙方现场施工（作业或服务）或取消乙方合格供应商资格。
# << STYLE: Normal >>
# 个性化条款
# << STYLE: Normal >>
# 杀虫类：
# << STYLE: Normal >>
# 乙方应具备从事此项工作所应具备的危险化学品安全使用许可证；同时如本项工作须取得行政备案或审批的，应由乙方先取得许可或备案；如因此导致甲方行政责任的，扣除乙方全部工程款。
# << STYLE: Normal >>
# 。
# << STYLE: Normal >>
# 乙方操作人员在虫害治理期间发生安全事故全部由乙方自行承担；乙方作为专业杀虫企业应做好杀虫的环保措施，因杀虫引发周边及环保纠纷由乙方负责处理，相关赔偿由乙方负责，并扣除乙方工程款 。
# << STYLE: Normal >>
# 通用物资运输类：
# << STYLE: Normal >>
# 乙方在规定地点实施装卸作业，应服从甲方现场管理人员要求实施有序装卸，发生违规强行插队装卸作业的行为处罚500元。
# << STYLE: Normal >>
# 乙方从业人员需取得国家相应的职业资格证书，如发现未取得相应职业资格的从业作业人员每人处罚200元。
# << STYLE: Normal >>
# 危险物资运输类：
# << STYLE: Normal >>
# 乙方在规定地点实施装卸作业，应服从甲方现场管理人员要求实施有序装卸，发生违规强行插队装卸作业的行为处罚500元。
# << STYLE: Normal >>
# 乙方应具备从事此项工作所应具备的危险化学品安全使用许可证；同时如本项工作须取得行政备案或审批的，应由乙方先取得许可或备案；如因此导致甲方行政责任的，应予以扣除乙方全部履约保证金。
# << STYLE: Normal >>
# 乙方运输车辆应符合中华人民共和国交通运输部颁布的《道路危险货物运输管理规定》，装卸及转运工具应符合国家及行业相关安全管理规定，如发现一次不符合国家强制规定的应予以处罚1000元。
# << STYLE: Normal >>
# 乙方从业人员需取得国家相应的职业资格证书，如发现未取得相应职业资格的从业作业人员每人处罚500 元。
# << STYLE: Normal >>
# 建筑施工和拆除、房屋修缮和装修装潢、设备设施安装拆除和维修保养类：
# << STYLE: Normal >>
# 洞口、临边无安全防护措施、安全防护措施不符合相关规范要求、无安全标志、安全标志不符合相关规范要求的每处扣除200元。
# << STYLE: Normal >>
# 搭建临时工棚、挖土、围墙改造等作业行为未经甲方安全管理部门批准，或虽经批准但搭建不符合安全要求的，每处处罚300元，并限期整改或拆除。
# << STYLE: Normal >>
# 乙方从业人员在甲方存在职业危害因素的场所作业时，严格按照江西中烟工业有限责任公司《劳动防护管理程序》的要求,督促从业人员正确佩带和使用防护用品；确保急性职业病危害事故为零。
# << STYLE: Normal >>
# 生产类生产性业务外包：
# << STYLE: Normal >>
# 乙方应制定火灾等事故应急预案，每半年应实施一次演练并记录备查。如缺少应急预案一项处罚500元；缺少一次演练记录处罚200 元。
# << STYLE: Normal >>
# 乙方从业人员在甲方存在职业危害因素的场所作业时，应按《中华人民共和国职业病防治法》的相关要求，必须进行上岗前、在岗期间、离岗时的职业性健康体检，完善健康监护档案，体检计划覆盖率100%。同时还应严格按照江西中烟工业有限责任公司《劳动防护管理程序》的要求,督促从业人员正确佩带和使用防护用品；确保急性职业病危害事故为零。
# << STYLE: Normal >>
# 食堂运行类：
# << STYLE: Normal >>
# 乙方从业人员需取得国家相应的职业资格证书、健康证书，如发现未取得相应职业资格的从业作业人员每人处罚200 元。
# << STYLE: Normal >>
# 乙方从业人员在甲方存在职业危害因素的场所作业时，应按《中华人民共和国职业病防治法》的相关要求，必须进行上岗前、在岗期间、离岗时的职业性健康体检，完善健康监护档案，体检计划覆盖率100%。同时还应严格按照甲方《劳动防护用品及劳保经费管理规定》的要求,督促从业人员正确佩带和使用防护用品；确保急性职业病危害事故为零。
# << STYLE: Normal >>
# 乙方按甲方要求担负食材采购配送任务，配送的食材出现质量安全问题，一切责任由乙方承担。
# << STYLE: Normal >>
# 乙方应参与甲方组织的应急演练，每半年应实施一次演练并记录备查。如缺少一次演练记录处罚200 元。
# << STYLE: Normal >>
# 绿化保洁、外墙清洗类：
# << STYLE: Normal >>
# 乙方从业人员需取得国家相应的职业资格证书，如发现未取得相应职业资格的从业作业人员每人处罚200元。
# << STYLE: Normal >>
# 保安、消防、物业服务类：
# << STYLE: Normal >>
# 乙方应与甲方组织的火灾等事故应急预案，缺少一次演练记录处罚200 元。
# << STYLE: Normal >>
# 乙方应切实履行安保服务、消防服务、物业服务采购合同的相关约定与要求，建立健全服务措施，不断改善服务质量，控制安保服务、消防服务、物业服务范围内的发案率。
# << STYLE: Normal >>
# 其它内容
# << STYLE: Normal >>
# 甲方项目业务实施部门严格执行企业安全管理制度，落实制度执行情况，并按制度要求进行项目的日常安全检查、整改和考核、评价。
# << STYLE: Normal >>
# 甲方属地管理部门、安全管理部门按照相关方管理要求对项目安全工作进行检查和考核。
# << STYLE: Normal >>
# 乙方因人员、设备、作业、原辅材料的安全风险管控和隐患排查治理管理不善造成风险失控和安全隐患的，甲方业务实施部门应及时约谈乙方项目负责人；乙方应制定风险控制措施和安全隐患排查治理措施。
# << STYLE: Normal >>
# 本协议有效期为商务合同约定期限，履约验收合格、质保期满后本协议自行终止。
# << STYLE: Normal >>
# 本协议一式肆份，甲方叁份，乙方壹份。经甲乙双方代表签字盖公章后生效,与商务合同具有同等法律效力。
# << STYLE: Normal >>
# 本协议中未尽事宜，需要明确的，经甲乙双方协商后，可签订补充协议。
# << STYLE: Normal >>
# 本协议有效期为商务合同约定期限，施工（维修）项目竣工验收合格、质保期、服务期满后本协议自行终止。
# << STYLE: Normal >>
#
# << STYLE: 段 >>
#
# << STYLE: 段 >>
#
# << STYLE: 附录章标题 >>
# 重点相关方管理台账
# << STYLE: 附录表标题 >>
# 重点相关方管理台账
# << STYLE: 附录表标题 >>
# 编号：
# << STYLE: 段 >>
#
# << STYLE: 段 >>
#
# << STYLE: 段 >>
#
# << STYLE: 段 >>
#
# << STYLE: 段 >>
#
# << STYLE: 附录章标题 >>
# 重点相关方绩效评价表
# << STYLE: 附录表标题 >>
# 重点相关方绩效评价表
# << STYLE: 段 >>
#
# << STYLE: 段 >>
# 注：属地管理部门牵涉到几个就要这几个部门都要进行评价。
# << STYLE: 附录章标题 >>
# 来访人员接洽单
# << STYLE: 附录表标题 >>
# 来访人员接洽单
# << STYLE: 段 >>
# 编号：
# << STYLE: Normal >>
# 注：来访人员持此单见接访人，受访人签字确认后，交门卫放行
# << STYLE: Normal >>
# 告   知  书
# << STYLE: Normal >>
# 1、各位来访人员，请遵守我厂各项规章制度，服从管理，厂区内已安装监控系统。
# << STYLE: Normal >>
# 2、我厂质量、环境、职业健康安全管理方针：一丝不苟、不优不休、以人为本、和谐共促、持续改进、追求卓越。
# << STYLE: Normal >>
# 3、进入厂区及生产区要求：
# << STYLE: Normal >>
# ——应与工作联系部门衔接。
# << STYLE: Normal >>
# ——进入生产区域应有相关部门人员陪同。
# << STYLE: Normal >>
# ——严禁流动吸烟。
# << STYLE: Normal >>
# ——禁止车辆乱停乱放。
# << STYLE: Normal >>
# ——车辆限速5公里/小时。
# << STYLE: Normal >>
# ——禁止鸣高音喇叭及大声喧哗。
# << STYLE: Normal >>
# ——未经同意严禁拍照。
# << STYLE: Normal >>
# ——不得随意偷拿卷烟及相关材料。
# << STYLE: Normal >>
# ——不得随意挪动厂区有关物品。
# << STYLE: Normal >>
# 以上告知内容本单位/本人已阅知并承诺严格执行。               相关方确认（签字）：                  确认日期：
# << STYLE: Normal >>
#
# << STYLE: 段 >>
#
# << STYLE: 终结线 >>
# _________________________________
