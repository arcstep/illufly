# %%
from illufly.llm import fake_llm, qwen
from illufly.desk import Desk

w = Desk(qwen, data_source="localhost")
w.load("xxx.xls", "这是新媒体运营数据")

# %%
w.chat("新媒体运营的AARRR是啥意思")
# Out:
# AARRR是新媒体运营或产品增长领域中常用的一个模型，代表了用户增长和参与的五个关键阶段。这个模型由Dave McClure提出，被广泛应用于互联网产品和内容策略的规划与优化中。AARRR分别代表以下几个阶段：
#
# 1. **Acquisition（获取）**：这一阶段关注的是如何获取新用户，包括用户从哪里来（如搜索引擎、社交媒体、广告等），以及通过哪些渠道获取的用户更有效。
#
# 2. **Activation（激活）**：激活指的是让用户完成首次有价值的操作，即让用户体会到产品或服务的核心价值。例如，对于一个社交媒体应用来说，激活可能意味着用户完成了个人资料的设置，关注了第一个账号，或者发布了第一条内容。
#
# 3. **Retention（留存）**：留存关注的是如何让用户持续回来使用产品。高留存率是产品成功的关键，因为保留现有用户通常比获取新用户成本更低。这涉及到提高用户粘性，通过内容、功能或社区等因素让用户形成习惯。
#
# 4. **Revenue（收入）**：在用户达到一定规模和活跃度后，考虑如何将用户基础转化为收入。这可能通过直接收费、广告、增值服务等多种方式实现。
#
# 5. **Referral（推荐）**：最后，当用户对产品满意时，他们可能会推荐给其他人，从而形成口碑传播。这一阶段的目标是鼓励和促进用户的推荐行为，因为来自朋友或信任来源的推荐是获取高质量新用户非常有效的方式。
#
# AARRR模型帮助运营者和产品经理系统地思考和优化产品的增长策略，从吸引用户到实现盈利，再到促进用户自发传播，形成一个良性循环。
# [{'role': 'user', 'content': '新媒体运营的AARRR是啥意思'},
#  {'role': 'assistant',
# ...

# %%
w.chat("用这个模型怎么生成最近一个月的数据分析情况")
# Out:
# 要使用AARRR模型生成最近一个月的数据分析情况，你需要针对每个阶段收集并分析相应的关键指标。下面是一个简化的步骤和示例指标，帮助你进行数据分析：
#
# ### 1. Acquisition（获取）
#
# - **指标示例**：
#   - **新用户数量**：统计最近一个月内新增的用户数。
#   - **渠道来源分析**：分析用户通过哪些渠道（如搜索引擎、社交媒体、广告、直接访问等）进入，以及各渠道的转化率。
#   - **获客成本（CAC）**：如果进行了付费推广，计算平均每个新用户的获取成本。
#
# ### 2. Activation（激活）
#
# - **指标示例**：
#   - **首次有价值操作完成率**：比如，注册后完成个人资料填写的用户比例，或首次登录后发布内容的用户比例。
#   - **激活用户数**：完成激活行为的用户总数。
#
# ### 3. Retention（留存）
#
# - **指标示例**：
#   - **日/周/月活跃用户数**：分别统计日、周、月活跃用户数，以及与上一周期的比较，分析留存率变化。
#   - **留存率曲线**：绘制7日留存、14日留存、30日留存等数据，分析用户随时间的流失情况。
#
# ### 4. Revenue（收入）
#
# - **指标示例**：
#   - **总收入**：统计最近一个月内的总收入。
#   - **付费用户比例**：付费用户占总用户的比例。
#   - **平均收入 per 用户（ARPU）**：总收入除以月活跃用户数。
#   - **转化率**：比如，免费用户转化为付费用户的比率。
#
# ### 5. Referral（推荐）
#
# - **指标示例**：
#   - **邀请发起量**：用户通过邀请功能发起的邀请总数。
#   - **通过邀请注册的新用户数**：通过邀请链接注册的新用户数量。
#   - **病毒系数（K因子）**：平均每个用户能带来多少新用户，用于衡量用户推荐的效率。
#
# ### 实施步骤：
#
# 1. **数据收集**：确保你的系统能够收集到上述所有指标所需的数据。
# 2. **数据分析**：使用数据分析工具（如Excel、Google Analytics、SQL查询等）对收集到的数据进行处理和分析。
# ...

# %%
w.chat("哪些地区支持了消防控制室的单人值班政策？", enable_search=True)
# Out:
# 以下是中国境内已知支持消防控制室单人值班政策的一些地区，前提是消防控制室能够接入城市消防远程监控系统，实现远程操作所有控制功能：
#
# 1. 广西
# 2. 福建
# 3. 浙江
# 4. 广东
# 5. 重庆
# 6. 四川（自2024年5月起实施）
#
# 这些信息表明，通过技术进步和远程监控系统的普及，越来越多的地区开始采纳单人值班政策，前提是能够确保消防安全和快速响应能力。不过，具体政策细节、实施条件及时间可能有所变化，建议联系当地消防主管部门或查阅最新的官方文件以获取最新、最准确的信息。
# [{'role': 'user', 'content': '哪些地区支持了消防控制室的单人值班政策？'},
#  {'role': 'assistant',
#   'content': '关于消防控制室单人值班政策的支持地区，具体规定可能因国家和地区的法律法规、行业标准以及实际安全管理需求的不同而有所差异。一般而言，是否允许消防控制室单人值班取决于该地区的消防法规、安全管理标准及对技术手段的依赖程度。例如，一些地方可能允许在配备有先进自动化消防监控和报警系统的前提下实施单人值班，而其他地区可能要求必须有两名或以上值班人员以确保及时响应和处理火灾等紧急情况。\n\n在中国，根据《建筑消防设施的维护管理》（GB 25201-2010）等相关标准，虽然没有直接规定消防控制室必须是单人或双人值班，但通常强调应保证24小时有人值班，并且值班人员应具备相应资格。实际操作中，很多地方倾向于采用双人或以上值班制度，以确保能够及时、有效地处理突发情况。\n\n要了解具体哪些地区支持消防控制室单人值班政策，需要查阅当地消防部门发布的最新规定或指导文件，因为这些政策可能会随着技术进步和安全标准的更新而发生变化。因此，建议直接咨询当地消防管理部门或参考最新的地方性消防管理条例和规范。'},
#  {'role': 'user', 'content': '哪些地区支持了消防控制室的单人值班政策？'},
#  {'role': 'assistant',
# ...

# %%
w.chat("你数一数，这句话逗号之前有多少个字，给出理由", new_chat=True)
# Out:
# 这句话，“你数一数，这句话逗号之前有多少个字，给出理由”，在第一个逗号之前共有4个汉字，即“你数一数”。理由是，根据逗号的使用规则，它用于分隔句子中的不同成分，如分句、项目列举等。在这个句子中，第一个逗号用来分隔引言部分和具体的请求内容，因此我们只计算到第一个逗号为止的字数。
# [{'role': 'user', 'content': '你数一数，这句话逗号之前有多少个字，给出理由'},
#  {'role': 'assistant',
#   'content': '这句话，“你数一数，这句话逗号之前有多少个字，给出理由”，在第一个逗号之前共有4个汉字，即“你数一数”。理由是，根据逗号的使用规则，它用于分隔句子中的不同成分，如分句、项目列举等。在这个句子中，第一个逗号用来分隔引言部分和具体的请求内容，因此我们只计算到第一个逗号为止的字数。'}]
