# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
from textlong.writing import write, idea, outline, from_outline
from textlong.parser import parse_markdown
from langchain_zhipu import ChatZhipuAI

# %% [markdown]
# ## idea

# %%
x = idea(
    ChatZhipuAI(),
    task="帮我起一个公司名字，我希望基于现在流行的大语言模型AI实现自己研究的算法，为个人或公司提供长文本生成的业务（包括写作、整理资料、策划文案等等）",
    verbose=True
)
# Out:
# >->>> Prompt ID: IDEA <<<-<
# 你是强大的写作助手。
#
# 你的任务是：帮我起一个公司名字，我希望基于现在流行的大语言模型AI实现自己研究的算法，为个人或公司提供长文本生成的业务（包括写作、整理资料、策划文案等等）
#
# 你必须遵循以下约束来完成任务:
# 1. 直接输出你的结果，不要评论，不要啰嗦
# 2. 使用markdown格式输出，但不要强调markdown格式，也不要使用```符号包裹输出内容
# >>>>>>>>>>>>>>>>>>>> 输出例子：
# ...
# AIAssist文本创智公司
#
# 或者
#
# LexiGenius AI写作服务
#
# 或者
#
# TextMaster AI解决方案
#
# 或者
#
# InnovAItive Write公司
#
# 或者
#
# AI-Penman长文本服务

# %%
x
# Out:
# 'AIAssist文本创智公司\n\n或者\n\nLexiGenius AI写作服务\n\n或者\n\nTextMaster AI解决方案\n\n或者\n\nInnovAItive Write公司\n\n或者\n\nAI-Penman长文本服务'

# %% [markdown]
# ## 输出到文件

# %%
idea(
    ChatZhipuAI(),
    output_file="小说/起名字.md",
    task="帮我起一个公司名字，我希望基于现在流行的大语言模型AI实现自己研究的算法，为个人或公司提供长文本生成的业务（包括写作、整理资料、策划文案等等）",
    verbose=True
)
# Out:
# >->>> Prompt ID: IDEAIDEA | 小说/起名字.md <<<-<
# 你是强大的写作助手。
#
# 你的任务是：帮我起一个公司名字，我希望基于现在流行的大语言模型AI实现自己研究的算法，为个人或公司提供长文本生成的业务（包括写作、整理资料、策划文案等等）
#
# 你必须遵循以下约束来完成任务:
# 1. 直接输出你的结果，不要评论，不要啰嗦
# 2. 使用markdown格式输出，但不要强调markdown格式，也不要使用```符号包裹输出内容
# >>>>>>>>>>>>>>>>>>>> 输出例子：
# ...
# AIAssist文本创智公司
#
# 或者
#
# LangModelPlus方案实验室
#
# 或者
#
# AIWriter算法服务中心
#
# 或者
#
# TextForge AI 编鸺拦氛有限责任公司
#
# 请根据您的喜好和实际需求选择或调整。已保存 小说/起名字.md / 共计 9 字。
# 'AIAssist文本创智公司\n\n或者\n\nLangModelPlus方案实验室\n\n或者\n\nAIWriter算法服务中心\n\n或者\n\nTextForge AI 编鸺拦氛有限责任公司\n\n请根据您的喜好和实际需求选择或调整。'

# %% [markdown]
# ## outline

# %%
ol = outline(
    ChatZhipuAI(),
    task="我希望基于现在流行的大语言模型AI实现自己研究的算法，为个人或公司提供长文本生成的业务（包括写作、整理资料、策划文案等等），帮我策划一下营销推广该怎么做",
    verbose=True
)
# Out:
# >->>> Prompt ID: OUTLINE <<<-<
# 你是强大的写作助手。
#
# 你的任务是：我希望基于现在流行的大语言模型AI实现自己研究的算法，为个人或公司提供长文本生成的业务（包括写作、整理资料、策划文案等等），帮我策划一下营销推广该怎么做
#
# 你必须遵循以下约束来完成任务:
# 1. 直接输出你的结果，不要评论，不要啰嗦
# 2. 使用markdown格式输出，但不要强调markdown格式，也不要使用```符号包裹输出内容
# 3. 扩写要求中包括预估字数、创意要点、创作思路、创作中涉及到的实体名称等
# 4. 你必须确保每一部份的扩写要求被完整的 <OUTLINE>...</OUTLINE> 包裹
# 5. 你只能输出提纲，不要输出具体的扩写内容
#
# >>>>>>>>>>>>>>>>>>>> 标题格式参考:
# # 第一章 标题1
# ## 一、标题2
# ### 1、标题3
# **（1）标题4**
#
#
#
# >>>>>>>>>>>>>>>>>>>> 输出例子：
# # XXX
# ## XXX
# <OUTLINE>
# 扩写摘要...
#
# 扩写要求：
# - xxx
# - xxx
# </OUTLINE>
#
# **按需增加N个 <OUTLINE>...</OUTLINE>**
# # 营销推广策划
#
# ## 一、市场定位与目标客户
# <OUTLINE>
# 对目标市场进行定位，明确目标客户群体。
#
# 扩写要求：
# - 预估字数：200字
# - 创意要点：阐述算法服务的独特优势，如个性化、高质量、高效率等
# - 创作思路：分析当前市场需求，结合算法特点进行市场定位
# - 涉及实体名称：目标市场、目标客户群体
# </OUTLINE>
#
# ## 二、营销策略
# ### 1、产品策略
# <OUTLINE>
# 介绍产品特点，以满足客户需求。
#
# 扩写要求：
# - 预估字数：300字
# - 创意要点：展示算法在不同场景下的应用，如文章写作、资料整理等
# - 创作思路：从客户角度出发，突出产品优势
# - 涉及实体名称：产品特点、应用场景
# </OUTLINE>
#
# ### 2、价格策略
# <OUTLINE>
# 设定合理的价格策略，以吸引更多客户。
#
# 扩写要求：
# ...

# %%
ol
# Out:
# '# 营销推广策划\n\n## 一、市场调研\n<OUTLINE>\n对目标市场进行深入分析，了解潜在客户的需求和痛点。\n\n扩写要求：\n- 目标市场描述\n- 竞争对手分析\n- 客户需求与痛点调研\n- 预估字数：1000字\n</OUTLINE>\n\n## 二、品牌定位\n<OUTLINE>\n明确品牌核心价值，树立品牌形象。\n\n扩写要求：\n- 品牌核心价值观\n- 品牌视觉识别系统（VI）\n- 品牌口号\n- 预估字数：500字\n</OUTLINE>\n\n## 三、推广策略\n### 1、线上推广\n<OUTLINE>\n制定线上推广方案，包括社交媒体、搜索引擎等渠道。\n\n扩写要求：\n- 线上推广渠道选择\n- 内容策划与创意要点\n- 互动营销策略\n- 预估字数：800字\n</OUTLINE>\n\n### 2、线下推广\n<OUTLINE>\n制定线下推广方案，包括活动策划、展会等。\n\n扩写要求：\n- 线下活动类型与创意\n- 合作与赞助方案\n- 媒体报道与公关\n- 预估字数：800字\n</OUTLINE>\n\n## 四、合作伙伴\n<OUTLINE>\n寻找潜在的合作伙伴，共同扩大业务范围。\n\n扩写要求：\n- 合作伙伴筛选标准\n- 合作模式与共赢策略\n- 合作伙伴名录\n- 预估字数：600字\n</OUTLINE>\n\n## 五、营销预算与效果评估\n<OUTLINE>\n制定营销预算，并对推广效果进行评估。\n\n扩写要求：\n- 营销预算分配\n- 效果评估指标\n- 数据分析与优化策略\n- 预估字数：600字\n</OUTLINE>'

# %% [markdown]
# ## from_outline

# %%
final_md = from_outline(ChatZhipuAI(), input=ol, verbose=True)
# Out:
# >->>> Prompt ID: FROM_OUTLINE <<<-<
#
# sep_mode: outline
# task_mode: document
# ...

# %%
print(final_md)
# Out:
# # 营销推广策划
#
#
# ## 一、市场调研与分析
#
# 在进行营销推广策划之前，我们首先对目标市场进行了深入的调研与分析。这一阶段的工作主要包括行业需求分析、竞争对手分析以及目标客户群体画像。
#
# 在网络调查和问卷调查等手段的辅助下，我们收集了大量与行业相关的数据。结合行业报告，我们对这些数据进行了深度剖析，以掌握当前行业的发展趋势和潜在客户的需求。
#
# 行业需求分析显示，当前市场对创新、高品质和便捷性的产品需求日益增长。这一发现为我们后续的产品开发和营销策略提供了重要参考。
#
# 在竞争对手分析方面，我们选取了行业内的主要竞争对手，从产品特点、市场份额、营销策略等多个维度进行对比分析。通过这一过程，我们发现了竞争对手的优势和劣势，从而为我们的品牌定位和营销策略制定提供了依据。
#
# 此外，我们还对目标客户群体进行了详细的画像。潜在客户主要集中在年轻人群、中产阶级以及专业人士等。他们追求生活品质，注重产品个性化和用户体验。了解这些特点后，我们可以有针对性地开展后续的营销活动，提高推广效果。
#
# 综上所述，通过对目标市场的调研与分析，我们掌握了行业趋势、竞争对手情况和目标客户需求。这些成果将为我们的营销推广策划提供有力支持。
#
# ## 二、品牌定位与核心价值主张
#
# 在我们深入理解了市场趋势和客户需求后，接下来便是确立品牌定位和提炼核心价值主张。品牌定位是构建品牌个性的核心，是我们在市场竞争中区别于其他品牌的关键。我们的品牌定位立足于产品独特的卖点和深厚的公司背景，致力于传递一种与目标客户情感共鸣的品牌故事。
#
# 公司自成立以来，始终秉承“创新、品质、服务”的理念，在不断的研发和实践中形成了独有的产品特点。我们的产品不仅具备前沿的技术创新，还兼具优雅的设计和便捷的用户体验。这些特点成为了我们塑造品牌定位的基石。
#
# 在创意构思中，我们围绕“独特卖点”构建了品牌故事。这个故事灵感来源于创始人的个人经历，他曾在旅途中深受传统产品的不便之苦，因而立志创造能够真正改善人们生活的产品。这一故事不仅赋予了品牌深厚的人文背景，还紧密地将产品特点与目标客户追求生活品质的需求相结合。
#
# ...
