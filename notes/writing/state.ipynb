# %% [markdown]
# ## ContentState

# %%
from langchain_chinese import ContentState

# %%
s = ContentState()

# %%
s
# Out:
# ContentState(model=Model(state=init), state_field='state', current_state='init')

# %%
s.current_state
# Out:
# State('init', id='init', value='init', initial=True, final=False)

# %%
s.init_todo()
# Out:
# <#init> ok

# %%
s
# Out:
# ContentState(model=Model(state=todo), state_field='state', current_state='todo')

# %%
s.todo_done()
# Out:
# <#todo> ok

# %%
s.done_todo()
# Out:
# 存在扩写指南
# 存在生成结果
# <#done> todo

# %%
s.todo_done()
# Out:
# <#todo> ok

# %%
s.done_mod()
# Out:
# 存在扩写指南
# 不存在生成结果
# <#done> mod

# %%
s.mod_todo()
# Out:
# <#todo> ok

# %%
s.todo_done()
# Out:
# <#todo> ok

# %%
s.done_mod()
# Out:
# 存在扩写指南
# 不存在生成结果
# <#done> mod
