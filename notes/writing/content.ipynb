# %% [markdown]
# ## TreeContent

# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)

os.chdir('..')

# %%
from langchain_chinese import TreeContent

# %%
c = TreeContent()

# %%
c
# Out:
# TreeContent(model=Model(state=init), state_field='state', current_state='init')

# %%
print(c)
# Out:
# <TreeContent id:0, children:[]>

# %%
c.last_ai_reply_json = {
    "标题名称": "一篇小作文",
    "总字数要求": 400,
    "扩写指南": "请好好写"
}
c.init_todo()
# Out:
# <#init> ok

# %%
c.title
# Out:
# '一篇小作文'

# %%
c.id
# Out:
# '0'

# %%
c.last_ai_reply_json = {
    "内容摘要": "你行你上",
    "详细内容": "来来来，你行你上",
}
c.todo_done()

# %%
print(c.summarise)
# Out:
# 你行你上

# %%
c.type
