# %%
from textlong.md.documents import IntelliDocuments
from textlong.parser import parse_markdown
from textlong.utils import markdown

# %%
md = """
## 前序

# 标题1
我的文档。

<OUTLINE>
扩写依据:
你说的有道理
</OUTLINE>

## 第一个标题2

逍遥老仙，

逍遥小仙，

<OUTLINE>
扩写依据：帮我描述一下逍遥老仙的威武霸气
</OUTLINE>

那又是谁？

<OUTLINE>
扩写依据：帮我描述一下逍遥小仙的武功盖世
## 宁厌烦
## 宁雪
</OUTLINE>

## 第二个标题2

法力无边。

### 标题3 

倚天不出，谁与争锋。

## 第三个标题2

华山论剑。
"""

# %% [markdown]
# # Parse

# %%
parse_markdown(md)
# Out:
# [Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745672-0'}),
#  Document(page_content='## 前序\n\n', metadata={'type': 'heading', 'attrs': {'level': 2}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '前序'}], 'id': '1717745672-1'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745672-2'}),
#  Document(page_content='# 标题1\n\n', metadata={'type': 'heading', 'attrs': {'level': 1}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '标题1'}], 'id': '1717745672-3'}),
#  Document(page_content='我的文档。\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '我的文档。'}], 'id': '1717745672-4'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745672-5'}),
#  Document(page_content='<OUTLINE>\n扩写依据:\n你说的有道理\n</OUTLINE>\n\n', metadata={'id': '1717745672-6', 'type': 'OUTLINE'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745672-7'}),
#  Document(page_content='## 第一个标题2\n\n', metadata={'type': 'heading', 'attrs': {'level': 2}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '第一个标题2'}], 'id': '1717745672-8'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745672-9'}),
#  Document(page_content='逍遥老仙，\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '逍遥老仙，'}], 'id': '1717745672-10'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745672-11'}),
#  Document(page_content='逍遥小仙，\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '逍遥小仙，'}], 'id': '1717745672-12'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745672-13'}),
#  Document(page_content='<OUTLINE>\n扩写依据：帮我描述一下逍遥老仙的威武霸气\n</OUTLINE>\n\n', metadata={'id': '1717745672-14', 'type': 'OUTLINE'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745672-15'}),
#  Document(page_content='那又是谁？\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '那又是谁？'}], 'id': '1717745672-16'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745672-17'}),
#  Document(page_content='<OUTLINE>\n扩写依据：帮我描述一下逍遥小仙的武功盖世\n## 宁厌烦\n## 宁雪\n</OUTLINE>\n\n', metadata={'id': '1717745672-18', 'type': 'OUTLINE'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745672-19'}),
#  Document(page_content='## 第二个标题2\n\n', metadata={'type': 'heading', 'attrs': {'level': 2}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '第二个标题2'}], 'id': '1717745672-20'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745672-21'}),
#  Document(page_content='法力无边。\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '法力无边。'}], 'id': '1717745672-22'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745672-23'}),
#  Document(page_content='### 标题3\n\n', metadata={'type': 'heading', 'attrs': {'level': 3}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '标题3'}], 'id': '1717745672-24'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745672-25'}),
#  Document(page_content='倚天不出，谁与争锋。\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '倚天不出，谁与争锋。'}], 'id': '1717745672-26'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745672-27'}),
#  Document(page_content='## 第三个标题2\n\n', metadata={'type': 'heading', 'attrs': {'level': 2}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '第三个标题2'}], 'id': '1717745672-28'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745672-29'}),
#  Document(page_content='华山论剑。\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '华山论剑。'}], 'id': '1717745672-30'})]

# %% [markdown]
# # IntelliDocuments

# %% [markdown]
# ## `__init__`

# %%
t = IntelliDocuments(md)
print(t.markdown)
# Out:
# ## 前序
#
# # 标题1
#
# 我的文档。
#
# <OUTLINE>
# 扩写依据:
# 你说的有道理
# </OUTLINE>
#
# ## 第一个标题2
#
# 逍遥老仙，
#
# 逍遥小仙，
#
# <OUTLINE>
# 扩写依据：帮我描述一下逍遥老仙的威武霸气
# </OUTLINE>
#
# 那又是谁？
#
# <OUTLINE>
# 扩写依据：帮我描述一下逍遥小仙的武功盖世
# ## 宁厌烦
# ## 宁雪
# </OUTLINE>
#
# ## 第二个标题2
#
# 法力无边。
#
# ### 标题3
#
# 倚天不出，谁与争锋。
#
# ## 第三个标题2
#
# 华山论剑。

# %% [markdown]
# ## get_outline_task

# %%
tasks = t.get_outline_task()
# print(markdown(tasks, "\n---------------\n"))

tasks
# Out:
# [Document(page_content='<OUTLINE>\n扩写依据:\n你说的有道理\n</OUTLINE>\n\n', metadata={'id': '1717745677-6', 'type': 'OUTLINE'}),
#  Document(page_content='<OUTLINE>\n扩写依据：帮我描述一下逍遥老仙的威武霸气\n</OUTLINE>\n\n', metadata={'id': '1717745677-14', 'type': 'OUTLINE'}),
#  Document(page_content='<OUTLINE>\n扩写依据：帮我描述一下逍遥小仙的武功盖世\n## 宁厌烦\n## 宁雪\n</OUTLINE>\n\n', metadata={'id': '1717745677-18', 'type': 'OUTLINE'})]

# %% [markdown]
# ## get_relevant_documents

# %%
tasks[0]
# Out:
# Document(page_content='<OUTLINE>\n扩写依据:\n你说的有道理\n</OUTLINE>\n\n', metadata={'id': '1717745677-6', 'type': 'OUTLINE'})

# %%
t.get_prev_documents(tasks[2], k=110)
# Out:
# [Document(page_content='# 标题1\n\n', metadata={'type': 'heading', 'attrs': {'level': 1}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '标题1'}], 'id': '1717745677-3'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745677-5'}),
#  Document(page_content='<OUTLINE>\n扩写依据:\n你说的有道理\n</OUTLINE>\n\n', metadata={'id': '1717745677-6', 'type': 'OUTLINE'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745677-7'}),
#  Document(page_content='## 第一个标题2\n\n', metadata={'type': 'heading', 'attrs': {'level': 2}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '第一个标题2'}], 'id': '1717745677-8'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745677-9'}),
#  Document(page_content='逍遥老仙，\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '逍遥老仙，'}], 'id': '1717745677-10'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745677-11'}),
#  Document(page_content='逍遥小仙，\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '逍遥小仙，'}], 'id': '1717745677-12'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745677-13'}),
#  Document(page_content='<OUTLINE>\n扩写依据：帮我描述一下逍遥老仙的威武霸气\n</OUTLINE>\n\n', metadata={'id': '1717745677-14', 'type': 'OUTLINE'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745677-15'}),
#  Document(page_content='那又是谁？\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '那又是谁？'}], 'id': '1717745677-16'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717745677-17'})]

# %%
print(markdown(t.get_prev_documents(tasks[2], k=110)))
# Out:
# # 标题1
#
# <OUTLINE>
# 扩写依据:
# 你说的有道理
# </OUTLINE>## 第一个标题2
#
# 逍遥老仙，
#
# 逍遥小仙，
#
# <OUTLINE>
# 扩写依据：帮我描述一下逍遥老仙的威武霸气
# </OUTLINE>那又是谁？

# %%
print(markdown([tasks[2]]))
# Out:
# <OUTLINE>
# 扩写依据：帮我描述一下逍遥小仙的武功盖世
# ## 宁厌烦
# ## 宁雪
# </OUTLINE>

# %%
print(markdown(t.get_next_documents(tasks[2], k=110)))
# Out:
# ## 第二个标题2
#
# 法力无边。
#
# ### 标题3
#
# 倚天不出，谁与争锋。
#
# ## 第三个标题2
#
# 华山论剑。

# %%
tasks
# Out:
# [Document(page_content='<OUTLINE>\n扩写依据:\n你说的有道理\n</OUTLINE>', metadata={'id': '1717661222-6', 'type': 'OUTLINE'}),
#  Document(page_content='<OUTLINE>\n扩写依据：帮我描述一下逍遥老仙的威武霸气\n</OUTLINE>', metadata={'id': '1717661222-14', 'type': 'OUTLINE'}),
#  Document(page_content='<OUTLINE>\n扩写依据：帮我描述一下逍遥小仙的武功盖世\n## 宁厌烦\n## 宁雪\n</OUTLINE>', metadata={'id': '1717661222-18', 'type': 'OUTLINE'})]

# %%
markdown = """
## 一、安装

你可以使用 pip 安装：
```
pip install -U textlong
```

或者使用 poetry 安装：
```
poetry add textlong@latest
```
"""

IntelliDocuments(markdown).documents
# t.documents
t.replace_documents(tasks[2], IntelliDocuments(markdown).documents)
# Out:
# [Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661222-0'}),
#  Document(page_content='## 前序\n\n', metadata={'type': 'heading', 'attrs': {'level': 2}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '前序'}], 'id': '1717661222-1'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661222-2'}),
#  Document(page_content='# 标题1\n\n', metadata={'type': 'heading', 'attrs': {'level': 1}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '标题1'}], 'id': '1717661222-3'}),
#  Document(page_content='我的文档。\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '我的文档。'}], 'id': '1717661222-4'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661222-5'}),
#  Document(page_content='<OUTLINE>\n扩写依据:\n你说的有道理\n</OUTLINE>', metadata={'id': '1717661222-6', 'type': 'OUTLINE'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661222-7'}),
#  Document(page_content='## 第一个标题2\n\n', metadata={'type': 'heading', 'attrs': {'level': 2}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '第一个标题2'}], 'id': '1717661222-8'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661222-9'}),
#  Document(page_content='逍遥老仙，\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '逍遥老仙，'}], 'id': '1717661222-10'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661222-11'}),
#  Document(page_content='逍遥小仙，\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '逍遥小仙，'}], 'id': '1717661222-12'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661222-13'}),
#  Document(page_content='<OUTLINE>\n扩写依据：帮我描述一下逍遥老仙的威武霸气\n</OUTLINE>', metadata={'id': '1717661222-14', 'type': 'OUTLINE'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661222-15'}),
#  Document(page_content='那又是谁？\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '那又是谁？'}], 'id': '1717661222-16'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661222-17'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661225-0'}),
#  Document(page_content='## 一、安装\n\n', metadata={'type': 'heading', 'attrs': {'level': 2}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '一、安装'}], 'id': '1717661225-1'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661225-2'}),
#  Document(page_content='你可以使用 pip 安装：\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '你可以使用 pip 安装：'}], 'id': '1717661225-3'}),
#  Document(page_content='```\npip install -U textlong\n```\n\n', metadata={'type': 'block_code', 'raw': 'pip install -U textlong\n', 'style': 'fenced', 'marker': '```', 'id': '1717661225-4'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661225-5'}),
#  Document(page_content='或者使用 poetry 安装：\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '或者使用 poetry 安装：'}], 'id': '1717661225-6'}),
#  Document(page_content='```\npoetry add textlong@latest\n```\n\n', metadata={'type': 'block_code', 'raw': 'poetry add textlong@latest\n', 'style': 'fenced', 'marker': '```', 'id': '1717661225-7'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661275-0'}),
#  Document(page_content='## 一、安装\n\n', metadata={'type': 'heading', 'attrs': {'level': 2}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '一、安装'}], 'id': '1717661275-1'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661275-2'}),
#  Document(page_content='你可以使用 pip 安装：\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '你可以使用 pip 安装：'}], 'id': '1717661275-3'}),
#  Document(page_content='```\npip install -U textlong\n```\n\n', metadata={'type': 'block_code', 'raw': 'pip install -U textlong\n', 'style': 'fenced', 'marker': '```', 'id': '1717661275-4'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661275-5'}),
#  Document(page_content='或者使用 poetry 安装：\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '或者使用 poetry 安装：'}], 'id': '1717661275-6'}),
#  Document(page_content='```\npoetry add textlong@latest\n```\n\n', metadata={'type': 'block_code', 'raw': 'poetry add textlong@latest\n', 'style': 'fenced', 'marker': '```', 'id': '1717661275-7'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661222-19'}),
#  Document(page_content='## 第二个标题2\n\n', metadata={'type': 'heading', 'attrs': {'level': 2}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '第二个标题2'}], 'id': '1717661222-20'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661222-21'}),
#  Document(page_content='法力无边。\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '法力无边。'}], 'id': '1717661222-22'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661222-23'}),
#  Document(page_content='### 标题3\n\n', metadata={'type': 'heading', 'attrs': {'level': 3}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '标题3'}], 'id': '1717661222-24'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661222-25'}),
#  Document(page_content='倚天不出，谁与争锋。\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '倚天不出，谁与争锋。'}], 'id': '1717661222-26'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661222-27'}),
#  Document(page_content='## 第三个标题2\n\n', metadata={'type': 'heading', 'attrs': {'level': 2}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '第三个标题2'}], 'id': '1717661222-28'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717661222-29'}),
#  Document(page_content='华山论剑。\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '华山论剑。'}], 'id': '1717661222-30'})]

# %%
print(t.markdown)
# Out:
# ## 前序
#
# # 标题1
#
# 我的文档。
#
# <OUTLINE>
# 扩写依据:
# 你说的有道理
# </OUTLINE>## 第一个标题2
#
# 逍遥老仙，
#
# 逍遥小仙，
#
# <OUTLINE>
# 扩写依据：帮我描述一下逍遥老仙的威武霸气
# </OUTLINE>那又是谁？
#
# ## 一、安装
#
# 你可以使用 pip 安装：
#
# ```
# pip install -U textlong
# ```
#
# 或者使用 poetry 安装：
#
# ```
# poetry add textlong@latest
# ```
#
# ## 一、安装
#
# 你可以使用 pip 安装：
#
# ```
# pip install -U textlong
# ```
#
# 或者使用 poetry 安装：
#
# ```
# poetry add textlong@latest
# ```
#
# ## 第二个标题2
#
# 法力无边。
#
# ### 标题3
#
# 倚天不出，谁与争锋。
#
# ## 第三个标题2
#
# 华山论剑。

# %% [markdown]
# ## markdown: Code 标记

# %%
md = """
# 🦜🦜🦜 textlong
[![PyPI version](https://img.shields.io/pypi/v/textlong.svg)](https://pypi.org/project/textlong/)

**textlong** 的目标是基于大语言模型提供结构化的长文本生成能力。

## 一、安装

你可以使用 pip 安装：
```
pip install -U textlong
```

或者使用 poetry 安装：
```
poetry add textlong@latest
```

## 二、结构化长文生成能力

`textlong` 中提供如下创作工具：

- `WritingTask`：用于生成结构化长文

**1. 加载环境变量：**

```python
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
```

**2. 创建`WritingTask`实例：**

```python
from textlong import WritingTask
from langchain_openai import ChatOpenAI

task = WritingTask(llm=ChatOpenAI())
```

**3. 使用`auto_write`方法自动生成一段长文：**

```python
task.auto_write("task 给好基友写一封信, 1800字，分4段就行")
```

**4. 使用`repl_write`方法控制台，在人工干预过程中生成一段长文：**

```python
task.repl_write("task 给好基友写一封信, 1800字，分4段就行")

## ...
## 接下来，你可以一直输入 ok 指令确认生成的内容，获得与 auto_write 类似的效果
```

**5. 你可以查看生成的提纲（也可以在repl模式中输入 outlines）：**

```python
# 查看创作大纲
task.invoke("outlines")['reply']
```

**6. 或者查看文字成果：**

```python
task.invoke("texts")['reply']
```

**7. 使用`invoke`方法执行`help`指令，以获得帮助:**

```python
task.invoke("help 我在repl模式中还可以做什么？")
```

"""

# %%
from textlong.md import IntelliDocuments
t = IntelliDocuments(md)
t.documents
# Out:
# [Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-0'}),
#  Document(page_content='# 🦜🦜🦜 textlong\n\n', metadata={'type': 'heading', 'attrs': {'level': 1}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '🦜🦜🦜 textlong'}], 'id': '1717551010-1'}),
#  Document(page_content='[![PyPI version](https://img.shields.io/pypi/v/textlong.svg)](https://pypi.org/project/textlong/)\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'link', 'children': [{'type': 'image', 'children': [{'type': 'text', 'raw': 'PyPI version'}], 'attrs': {'url': 'https://img.shields.io/pypi/v/textlong.svg'}}], 'attrs': {'url': 'https://pypi.org/project/textlong/'}}], 'id': '1717551010-2'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-3'}),
#  Document(page_content='**textlong** 的目标是基于大语言模型提供结构化的长文本生成能力。\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'strong', 'children': [{'type': 'text', 'raw': 'textlong'}]}, {'type': 'text', 'raw': ' 的目标是基于大语言模型提供结构化的长文本生成能力。'}], 'id': '1717551010-4'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-5'}),
#  Document(page_content='## 一、安装\n\n', metadata={'type': 'heading', 'attrs': {'level': 2}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '一、安装'}], 'id': '1717551010-6'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-7'}),
#  Document(page_content='你可以使用 pip 安装：\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '你可以使用 pip 安装：'}], 'id': '1717551010-8'}),
#  Document(page_content='```\npip install -U textlong\n```\n\n', metadata={'type': 'block_code', 'raw': 'pip install -U textlong\n', 'style': 'fenced', 'marker': '```', 'id': '1717551010-9'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-10'}),
#  Document(page_content='或者使用 poetry 安装：\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '或者使用 poetry 安装：'}], 'id': '1717551010-11'}),
#  Document(page_content='```\npoetry add textlong@latest\n```\n\n', metadata={'type': 'block_code', 'raw': 'poetry add textlong@latest\n', 'style': 'fenced', 'marker': '```', 'id': '1717551010-12'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-13'}),
#  Document(page_content='## 二、结构化长文生成能力\n\n', metadata={'type': 'heading', 'attrs': {'level': 2}, 'style': 'axt', 'children': [{'type': 'text', 'raw': '二、结构化长文生成能力'}], 'id': '1717551010-14'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-15'}),
#  Document(page_content='`textlong` 中提供如下创作工具：\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'codespan', 'raw': 'textlong'}, {'type': 'text', 'raw': ' 中提供如下创作工具：'}], 'id': '1717551010-16'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-17'}),
#  Document(page_content='- `WritingTask`：用于生成结构化长文\n\n', metadata={'type': 'list', 'children': [{'type': 'list_item', 'children': [{'type': 'block_text', 'children': [{'type': 'codespan', 'raw': 'WritingTask'}, {'type': 'text', 'raw': '：用于生成结构化长文'}]}]}], 'tight': True, 'bullet': '-', 'attrs': {'depth': 0, 'ordered': False}, 'id': '1717551010-18'}),
#  Document(page_content='**1. 加载环境变量：**\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'strong', 'children': [{'type': 'text', 'raw': '1. 加载环境变量：'}]}], 'id': '1717551010-19'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-20'}),
#  Document(page_content='```python\nfrom dotenv import load_dotenv, find_dotenv\nload_dotenv(find_dotenv(), override=True)\n```\n\n', metadata={'type': 'block_code', 'raw': 'from dotenv import load_dotenv, find_dotenv\nload_dotenv(find_dotenv(), override=True)\n', 'style': 'fenced', 'marker': '```', 'attrs': {'info': 'python'}, 'id': '1717551010-21'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-22'}),
#  Document(page_content='**2. 创建`WritingTask`实例：**\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'strong', 'children': [{'type': 'text', 'raw': '2. 创建'}, {'type': 'codespan', 'raw': 'WritingTask'}, {'type': 'text', 'raw': '实例：'}]}], 'id': '1717551010-23'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-24'}),
#  Document(page_content='```python\nfrom textlong import WritingTask\nfrom langchain_openai import ChatOpenAI\n\ntask = WritingTask(llm=ChatOpenAI())\n```\n\n', metadata={'type': 'block_code', 'raw': 'from textlong import WritingTask\nfrom langchain_openai import ChatOpenAI\n\ntask = WritingTask(llm=ChatOpenAI())\n', 'style': 'fenced', 'marker': '```', 'attrs': {'info': 'python'}, 'id': '1717551010-25'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-26'}),
#  Document(page_content='**3. 使用`auto_write`方法自动生成一段长文：**\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'strong', 'children': [{'type': 'text', 'raw': '3. 使用'}, {'type': 'codespan', 'raw': 'auto_write'}, {'type': 'text', 'raw': '方法自动生成一段长文：'}]}], 'id': '1717551010-27'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-28'}),
#  Document(page_content='```python\ntask.auto_write("task 给好基友写一封信, 1800字，分4段就行")\n```\n\n', metadata={'type': 'block_code', 'raw': 'task.auto_write("task 给好基友写一封信, 1800字，分4段就行")\n', 'style': 'fenced', 'marker': '```', 'attrs': {'info': 'python'}, 'id': '1717551010-29'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-30'}),
#  Document(page_content='**4. 使用`repl_write`方法控制台，在人工干预过程中生成一段长文：**\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'strong', 'children': [{'type': 'text', 'raw': '4. 使用'}, {'type': 'codespan', 'raw': 'repl_write'}, {'type': 'text', 'raw': '方法控制台，在人工干预过程中生成一段长文：'}]}], 'id': '1717551010-31'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-32'}),
#  Document(page_content='```python\ntask.repl_write("task 给好基友写一封信, 1800字，分4段就行")\n\n## ...\n## 接下来，你可以一直输入 ok 指令确认生成的内容，获得与 auto_write 类似的效果\n```\n\n', metadata={'type': 'block_code', 'raw': 'task.repl_write("task 给好基友写一封信, 1800字，分4段就行")\n\n## ...\n## 接下来，你可以一直输入 ok 指令确认生成的内容，获得与 auto_write 类似的效果\n', 'style': 'fenced', 'marker': '```', 'attrs': {'info': 'python'}, 'id': '1717551010-33'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-34'}),
#  Document(page_content='**5. 你可以查看生成的提纲（也可以在repl模式中输入 outlines）：**\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'strong', 'children': [{'type': 'text', 'raw': '5. 你可以查看生成的提纲（也可以在repl模式中输入 outlines）：'}]}], 'id': '1717551010-35'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-36'}),
#  Document(page_content='```python\n# 查看创作大纲\ntask.invoke("outlines")[\'reply\']\n```\n\n', metadata={'type': 'block_code', 'raw': '# 查看创作大纲\ntask.invoke("outlines")[\'reply\']\n', 'style': 'fenced', 'marker': '```', 'attrs': {'info': 'python'}, 'id': '1717551010-37'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-38'}),
#  Document(page_content='**6. 或者查看文字成果：**\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'strong', 'children': [{'type': 'text', 'raw': '6. 或者查看文字成果：'}]}], 'id': '1717551010-39'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-40'}),
#  Document(page_content='```python\ntask.invoke("texts")[\'reply\']\n```\n\n', metadata={'type': 'block_code', 'raw': 'task.invoke("texts")[\'reply\']\n', 'style': 'fenced', 'marker': '```', 'attrs': {'info': 'python'}, 'id': '1717551010-41'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-42'}),
#  Document(page_content='**7. 使用`invoke`方法执行`help`指令，以获得帮助:**\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'strong', 'children': [{'type': 'text', 'raw': '7. 使用'}, {'type': 'codespan', 'raw': 'invoke'}, {'type': 'text', 'raw': '方法执行'}, {'type': 'codespan', 'raw': 'help'}, {'type': 'text', 'raw': '指令，以获得帮助:'}]}], 'id': '1717551010-43'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-44'}),
#  Document(page_content='```python\ntask.invoke("help 我在repl模式中还可以做什么？")\n```\n\n', metadata={'type': 'block_code', 'raw': 'task.invoke("help 我在repl模式中还可以做什么？")\n', 'style': 'fenced', 'marker': '```', 'attrs': {'info': 'python'}, 'id': '1717551010-45'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717551010-46'})]

# %%
print(t.markdown)
# Out:
# # 🦜🦜🦜 textlong
#
# [![PyPI version](https://img.shields.io/pypi/v/textlong.svg)](https://pypi.org/project/textlong/)
#
# **textlong** 的目标是基于大语言模型提供结构化的长文本生成能力。
#
# ## 一、安装
#
# 你可以使用 pip 安装：
#
# ```
# pip install -U textlong
# ```
#
# 或者使用 poetry 安装：
#
# ```
# poetry add textlong@latest
# ```
#
# ## 二、结构化长文生成能力
#
# `textlong` 中提供如下创作工具：
#
# - `WritingTask`：用于生成结构化长文
#
# **1. 加载环境变量：**
#
# ```python
# from dotenv import load_dotenv, find_dotenv
# load_dotenv(find_dotenv(), override=True)
# ```
#
# **2. 创建`WritingTask`实例：**
#
# ```python
# from textlong import WritingTask
# from langchain_openai import ChatOpenAI
#
# task = WritingTask(llm=ChatOpenAI())
# ```
#
# **3. 使用`auto_write`方法自动生成一段长文：**
#
# ```python
# task.auto_write("task 给好基友写一封信, 1800字，分4段就行")
# ```
#
# **4. 使用`repl_write`方法控制台，在人工干预过程中生成一段长文：**
#
# ```python
# task.repl_write("task 给好基友写一封信, 1800字，分4段就行")
#
# ## ...
# ## 接下来，你可以一直输入 ok 指令确认生成的内容，获得与 auto_write 类似的效果
# ```
#
# **5. 你可以查看生成的提纲（也可以在repl模式中输入 outlines）：**
#
# ```python
# # 查看创作大纲
# task.invoke("outlines")['reply']
# ```
#
# **6. 或者查看文字成果：**
#
# ```python
# task.invoke("texts")['reply']
# ```
#
# **7. 使用`invoke`方法执行`help`指令，以获得帮助:**
#
# ```python
# task.invoke("help 我在repl模式中还可以做什么？")
# ```

# %%
d = IntelliDocuments("/Users/xuehongwei/Documents/ebooks/arXiv/arXiv-2405.16900v1/document.md")

# %%
d.documents[3]
# Out:
# Document(page_content='## the Stiefel Manifold\n\n', metadata={'type': 'heading', 'style': 'setext', 'attrs': {'level': 2}, 'children': [{'type': 'text', 'raw': 'the Stiefel Manifold'}], 'id': '1717748377-3'})

# %%
d.documents
# Out:
# [Document(page_content='***\n\n', metadata={'type': 'thematic_break', 'id': '1717748377-0'}),
#  Document(page_content='abstract: |\nThis paper focus on investigating the distributed Riemannian\nstochastic optimization problem on the Stiefel manifold for\nmulti-agent systems, where all the agents work collaboratively to\noptimize a function modeled by the average of their expectation-valued\nlocal costs. Each agent only processes its own local cost function and\ncommunicate with neighboring agents to achieve optimal results while\nensuring consensus. Since the local Riemannian gradient in stochastic\nregimes cannot be directly calculated, we will estimate the gradient\nby the average of a variable number of sampled gradient, which however\nbrings about noise to the system. We then propose a distributed\nRiemannian stochastic optimization algorithm on the Stiefel manifold\nby combining the variable sample size gradient approximation method\nwith the gradient tracking dynamic. It is worth noticing that the\nsuitably chosen increasing sample size plays an important role in\nimproving the algorithm efficiency, as it reduces the noise variance.\nIn an expectation-valued sense, the iterates of all agents are proved\nto converge to a stationary point (or neighborhood) with fixed step\nsizes. We further establish the convergence rate of the iterates for\nthe cases when the sample size is exponentially increasing, polynomial\nincreasing, or a constant, respectively. Finally, numerical\nexperiments are implemented to demonstrate the theoretical results.\nauthor:\ntitle: Distributed Riemannian Stochastic Gradient Tracking Algorithm on\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'abstract: |'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'This paper focus on investigating the distributed Riemannian'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'stochastic optimization problem on the Stiefel manifold for'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'multi-agent systems, where all the agents work collaboratively to'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'optimize a function modeled by the average of their expectation-valued'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'local costs. Each agent only processes its own local cost function and'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'communicate with neighboring agents to achieve optimal results while'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'ensuring consensus. Since the local Riemannian gradient in stochastic'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'regimes cannot be directly calculated, we will estimate the gradient'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'by the average of a variable number of sampled gradient, which however'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'brings about noise to the system. We then propose a distributed'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'Riemannian stochastic optimization algorithm on the Stiefel manifold'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'by combining the variable sample size gradient approximation method'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'with the gradient tracking dynamic. It is worth noticing that the'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'suitably chosen increasing sample size plays an important role in'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'improving the algorithm efficiency, as it reduces the noise variance.'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'In an expectation-valued sense, the iterates of all agents are proved'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'to converge to a stationary point (or neighborhood) with fixed step'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'sizes. We further establish the convergence rate of the iterates for'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'the cases when the sample size is exponentially increasing, polynomial'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'increasing, or a constant, respectively. Finally ...
#  Document(page_content='- Jishu Zhao\n- Xi Wang\n- Jinlong Lei\n  bibliography:\n- reference.bib\n\n', metadata={'type': 'list', 'children': [{'type': 'list_item', 'children': [{'type': 'block_text', 'children': [{'type': 'text', 'raw': 'Jishu Zhao'}]}]}, {'type': 'list_item', 'children': [{'type': 'block_text', 'children': [{'type': 'text', 'raw': 'Xi Wang'}]}]}, {'type': 'list_item', 'children': [{'type': 'block_text', 'children': [{'type': 'text', 'raw': 'Jinlong Lei'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'bibliography:'}]}]}, {'type': 'list_item', 'children': [{'type': 'block_text', 'children': [{'type': 'text', 'raw': 'reference.bib'}]}]}], 'tight': True, 'bullet': '-', 'attrs': {'depth': 0, 'ordered': False}, 'id': '1717748377-2'}),
#  Document(page_content='## the Stiefel Manifold\n\n', metadata={'type': 'heading', 'style': 'setext', 'attrs': {'level': 2}, 'children': [{'type': 'text', 'raw': 'the Stiefel Manifold'}], 'id': '1717748377-3'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-4'}),
#  Document(page_content=':::: frontmatter\n::: keyword\nRiemannian optimization, Distributed stochastic optimization, Gradient\ntracking, Variable sampling scheme\n:::\n::::\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': ':::: frontmatter'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '::: keyword'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'Riemannian optimization, Distributed stochastic optimization, Gradient'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'tracking, Variable sampling scheme'}, {'type': 'softbreak'}, {'type': 'text', 'raw': ':::'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '::::'}], 'id': '1717748377-5'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-6'}),
#  Document(page_content='# Introduction {#sec-1}\n\n', metadata={'type': 'heading', 'attrs': {'level': 1}, 'style': 'axt', 'children': [{'type': 'text', 'raw': 'Introduction {#sec-1}'}], 'id': '1717748377-7'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-8'}),
#  Document(page_content='Distributed optimization has attracted much research attention in the\npast decades, motivated by the need to solve optimization problems over\nlarge-scale datasets or complex multi-agent systems. It is worth\nnoticing that some of the problems have particular manifold constraints,\ne.g. decentralized spectral analysis\n[@huang2020communication; @kempe2004decentralized], dictionary learning\n[@raja2015cloud], and deep neural networks with orthogonal constraint\n[@vorontsov2017orthogonality]. Therefore, solving distributed\noptimization problems on Riemannian manifold has also received\nsignificant research attention over the past few years\n[@pmlr-v139-chen21g; @deng2023decentralized; @wang2022decentralized; @doi:10.1137/20M1321000; @chen2024decentralized; @wang2022variance].\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'Distributed optimization has attracted much research attention in the'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'past decades, motivated by the need to solve optimization problems over'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'large-scale datasets or complex multi-agent systems. It is worth'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'noticing that some of the problems have particular manifold constraints,'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'e.g. decentralized spectral analysis'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@huang2020communication; @kempe2004decentralized], dictionary learning'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@raja2015cloud], and deep neural networks with orthogonal constraint'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@vorontsov2017orthogonality]. Therefore, solving distributed'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'optimization problems on Riemannian manifold has also received'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'significant research attention over the past few years'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@pmlr-v139-chen21g; @deng2023decentralized; @wang2022decentralized; @doi:10.1137/20M1321000; @chen2024decentralized; @wang2022variance].'}], 'id': '1717748377-9'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-10'}),
#  Document(page_content='Let $\\text{St}(n,r)$ denote the Stiefel manifold, and consider the\nfunction $f: \\text{St}(n,r) \\mapsto \\mathbb{R}$. We focus on the\nfollowing Riemannian stochastic optimization problem over connected\nnetworks: $$\\label{p-1}\n\\begin{aligned}\n\\min\\ &f(X) := \\frac{1}{N}\\sum_{i=1}^N f_i(X),\\\ns.t.\\ & X \\in \\mathcal{M} \\triangleq \\text{St}(n,r):={X \\in \\mathbb{R}^{n \\times r}:X^\\top X = I_r},\n\\end{aligned}$$ where $I_r$ is the $r\\times r$ identity matrix and\nthe local cost function privately known by agent $i$ is an\nexpectation-valued function defined as\n$f_i(X):=\\mathbb{E}_{\\xi_i} F_i(X,\\xi_i)$. Though each agent merely has\nits local information, it can interact with its neighbors through a\nconnected graph $\\mathcal{G}=(\\mathcal{N},\\mathcal{E})$ to\ncollaboratively solve the problem [[p-1]](#p-1){reference-type="eqref"\nreference="p-1"}. Here, $\\mathcal{N}:={1, \\dots , N}$ denotes the\nindex set including all agents, and\n$\\mathcal{E} \\subset \\mathcal{N} \\times \\mathcal{N}$ denotes the set of\nall communication links. If $(i,j)\\in \\mathcal{E}$, then node $i$ can\nsend information to node $j$. Problem\n[[p-1]](#p-1){reference-type="eqref" reference="p-1"} extends the\ndistributed stochastic optimization problem in Euclidean space to the\nStiefel manifold, which however is non-convex in Euclidean space. Next,\nwe initiate a review of prior work.\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'Let $\\text{St}(n,r)$ denote the Stiefel manifold, and consider the'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'function $f: \\text{St}(n,r) \\mapsto \\mathbb{R}$. We focus on the'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'following Riemannian stochastic optimization problem over connected'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'networks: $$\\label{p-1}'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '\\begin{aligned}'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '\\min\\ &f(X) := \\frac{1}{N}\\sum_{i=1}^N f_i(X),'}, {'type': 'text', 'raw': '\\'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 's.t.\\ & X \\in \\mathcal{M} \\triangleq \\text{St}(n,r):='}, {'type': 'text', 'raw': '{'}, {'type': 'text', 'raw': 'X \\in \\mathbb{R}^{n \\times r}:X^\\top X = I_r'}, {'type': 'text', 'raw': '}'}, {'type': 'text', 'raw': ','}, {'type': 'softbreak'}, {'type': 'text', 'raw': '\\end{aligned}$$ where $I_r$ is the $r\\times r$ identity matrix and'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'the local cost function privately known by agent $i$ is an'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'expectation-valued function defined as'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$f_i(X):=\\mathbb{E}'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': '{\\xi_i} F_i(X,\\xi_i)$. Though each agent merely has'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'its local information, it can interact with its neighbors through a'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'connected graph $\\mathcal{G}=(\\mathcal{N},\\mathcal{E})$ to'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'collaboratively solve the problem '}, {'type': 'link', 'children': [{'type': 'text', 'raw': '['}, {'type': 'text', 'raw': 'p-1'}, {'type': 'text', 'raw': ']'}], 'attrs': {'url': '#p-1'}}, {'type': 'text', 'raw': '{reference-type="eqref"'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'reference="p-1"}. Here, $\\mathcal{N}:='}, {'type': 'text', 'raw': '{'}, {'type': 'text', 'raw': '1, \\dots , N'}, {'type': 'text', 'raw': '}'}, {'type': 'text', 'raw': '$ denotes the'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'index set including all agents, and'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$\\mathcal{E} \\subset \\mathcal{N} \\times \\mathcal{N}$ denotes the set of'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'all communication links. If $(i,j)\\in \\mathcal{E}$, then node $i$ can'}, {'type': 'softbreak'}, {'type':  ...
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-12'}),
#  Document(page_content='## Related Works\n\n', metadata={'type': 'heading', 'attrs': {'level': 2}, 'style': 'axt', 'children': [{'type': 'text', 'raw': 'Related Works'}], 'id': '1717748377-13'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-14'}),
#  Document(page_content='Stochastic distributed optimization has particular research interests\namong various distributed optimization frameworks, where the local cost\nfunctions are the expectation of functions with stochastic variables.\nSince the expectation-valued function has no closed-form, it could be\nprohibitive or costly to compute the exact gradient in big-data\nscenarios. Stochastic approximation (SA), originated from Robbins and\nMonro in the 1950s [@robbins1951stochastic], is a commonly used method\nin algorithm design. The main idea of SA is to utilize a stochastic\ngradient to approximate the exact gradient. As such, stochastic gradient\ndescent (SGD) has received extensive attention since it is practical and\nperforms well in large-scale learning [@bottou2018optimization]. In\nrecent years, distributed stochastic optimization in the Euclidean space\nhas been widely studied where all the agents find the optimal solution\ncooperatively, such as\n[@nemirovski2009robust; @srivastava2011distributed; @pu2021distributed; @sayed2014adaptation; @lei2022distributed; @alghunaim2019distributed].\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'Stochastic distributed optimization has particular research interests'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'among various distributed optimization frameworks, where the local cost'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'functions are the expectation of functions with stochastic variables.'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'Since the expectation-valued function has no closed-form, it could be'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'prohibitive or costly to compute the exact gradient in big-data'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'scenarios. Stochastic approximation (SA), originated from Robbins and'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'Monro in the 1950s '}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@robbins1951stochastic], is a commonly used method'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'in algorithm design. The main idea of SA is to utilize a stochastic'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'gradient to approximate the exact gradient. As such, stochastic gradient'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'descent (SGD) has received extensive attention since it is practical and'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'performs well in large-scale learning '}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@bottou2018optimization]. In'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'recent years, distributed stochastic optimization in the Euclidean space'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'has been widely studied where all the agents find the optimal solution'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'cooperatively, such as'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@nemirovski2009robust; @srivastava2011distributed; @pu2021distributed; @sayed2014adaptation; @lei2022distributed; @alghunaim2019distributed].'}], 'id': '1717748377-15'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-16'}),
#  Document(page_content='However, it is unable to solve problem\n[[p-1]](#p-1){reference-type="eqref" reference="p-1"} directly using\nthe aforementioned studies since the Stiefel manifold constraint lacks\nof convexity and linearity. The analysis of distributed optimization\nalgorithms in the Euclidean space usually relies on the linear\nconvergence of consensus protocol, which however is difficult to obtain\non the manifolds. Since the Stiefel manifold can be viewed as an\nembedded submanifold in Euclidean space, there exist some recent\nliteratures that solve this problem from the viewpoint of treating it in\nEuclidean space and develop new tools with the help of Riemannian\noptimization [@AbsilMahonySepulchre+2008; @edelman1998geometry]. For\nexample, [@pmlr-v139-chen21g] proposed two methods called the\ndecentralized Riemannian SGD algorithm and the decentralized Riemannian\ngradient tracking algorithm, and established that their convergence rate\nare $\\mathcal{O}(1/\\sqrt{k})$ and $\\mathcal{O}(1/k)$, respectively. In\naddition, [@wang2022decentralized] proposed a computation-efficient\ngradient tracking algorithm by using the augmented Lagrangian method, in\nwhich the iterations stay in a neighborhood of the Stiefel manifold but\nfinally converge to the manifold with rate $\\mathcal{O}(1/k)$.\nFurthermore, [@deng2023decentralized] used the projection operators\ninstead of retractions and expanded the distributed Riemannian gradient\ndescent algorithm and the gradient tracking version to the compact\nsubmanifolds of Euclidean space. Besides, [@chen2024decentralized]\nproposed the first distributed Riemannian conjugate gradient algorithm\nand proved its global convergence over the Stiefel manifold.\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'However, it is unable to solve problem'}, {'type': 'softbreak'}, {'type': 'link', 'children': [{'type': 'text', 'raw': '['}, {'type': 'text', 'raw': 'p-1'}, {'type': 'text', 'raw': ']'}], 'attrs': {'url': '#p-1'}}, {'type': 'text', 'raw': '{reference-type="eqref" reference="p-1"} directly using'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'the aforementioned studies since the Stiefel manifold constraint lacks'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'of convexity and linearity. The analysis of distributed optimization'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'algorithms in the Euclidean space usually relies on the linear'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'convergence of consensus protocol, which however is difficult to obtain'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'on the manifolds. Since the Stiefel manifold can be viewed as an'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'embedded submanifold in Euclidean space, there exist some recent'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'literatures that solve this problem from the viewpoint of treating it in'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'Euclidean space and develop new tools with the help of Riemannian'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'optimization '}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@AbsilMahonySepulchre+2008; @edelman1998geometry]. For'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'example, '}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@pmlr-v139-chen21g] proposed two methods called the'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'decentralized Riemannian SGD algorithm and the decentralized Riemannian'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'gradient tracking algorithm, and established that their convergence rate'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'are $\\mathcal{O}(1/\\sqrt{k})$ and $\\mathcal{O}(1/k)$, respectively. In'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'addition, '}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@wang2022decentralized] proposed a computation-efficient'}, {'type': 'softbreak'}, {'type': 'text', 'ra ...
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-18'}),
#  Document(page_content='As far as we know, there are only two related works\n[@pmlr-v139-chen21g; @wang2022variance] investigating the distributed\nand stochastic optimization settings on the Stiefel manifold. In\n[@pmlr-v139-chen21g], the decentralized Riemannian SGD algorithm was\nproved to be convergent asymptotically with diminishing step sizes. In\naddition, [@wang2022variance] proposed an algorithm that converges with\na $\\mathcal{O}(1/k)$ rate, however, the iterates do not always stay on\nthe Stiefel manifold and can only be restricted in a neighborhood of the\nmanifold. Moreover, both [@pmlr-v139-chen21g] and [@wang2022variance]\nfocused on the finite sum problem, while we are devoted to the on-line\nproblem with expectation-valued cost functions. To the best of our\nknowledge, distributed algorithms for Riemannian stochastic optimization\non the Stiefel manifold with an exact convergence under constant step\nsizes have not been achieved yet.\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'As far as we know, there are only two related works'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@pmlr-v139-chen21g; @wang2022variance] investigating the distributed'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'and stochastic optimization settings on the Stiefel manifold. In'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@pmlr-v139-chen21g], the decentralized Riemannian SGD algorithm was'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'proved to be convergent asymptotically with diminishing step sizes. In'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'addition, '}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@wang2022variance] proposed an algorithm that converges with'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'a $\\mathcal{O}(1/k)$ rate, however, the iterates do not always stay on'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'the Stiefel manifold and can only be restricted in a neighborhood of the'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'manifold. Moreover, both '}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@pmlr-v139-chen21g] and '}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@wang2022variance]'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'focused on the finite sum problem, while we are devoted to the on-line'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'problem with expectation-valued cost functions. To the best of our'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'knowledge, distributed algorithms for Riemannian stochastic optimization'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'on the Stiefel manifold with an exact convergence under constant step'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'sizes have not been achieved yet.'}], 'id': '1717748377-19'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-20'}),
#  Document(page_content='## Contributions\n\n', metadata={'type': 'heading', 'attrs': {'level': 2}, 'style': 'axt', 'children': [{'type': 'text', 'raw': 'Contributions'}], 'id': '1717748377-21'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-22'}),
#  Document(page_content='This paper devoted to design an efficient algorithm for solving problem\n[[p-1]](#p-1){reference-type="eqref" reference="p-1"} under a\nconnected network. We combine the dynamic gradient tracking method with\na variable sample-size method and make the following contributions:\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'This paper devoted to design an efficient algorithm for solving problem'}, {'type': 'softbreak'}, {'type': 'link', 'children': [{'type': 'text', 'raw': '['}, {'type': 'text', 'raw': 'p-1'}, {'type': 'text', 'raw': ']'}], 'attrs': {'url': '#p-1'}}, {'type': 'text', 'raw': '{reference-type="eqref" reference="p-1"} under a'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'connected network. We combine the dynamic gradient tracking method with'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'a variable sample-size method and make the following contributions:'}], 'id': '1717748377-23'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-24'}),
#  Document(page_content='(1) We propose a distributed Riemannian stochastic algorithm on the\nStiefel manifold to solve problem [[p-1]](#p-1){reference-type="eqref"\nreference="p-1"}. Each agent estimates its local gradient by\nvariable-sampled stochastic gradients, then obtains the search direction\nbased on the combination of multi-step consensus protocol and a gradient\ntracking dynamic.\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '('}, {'type': 'text', 'raw': '1'}, {'type': 'text', 'raw': ')'}, {'type': 'text', 'raw': ' We propose a distributed Riemannian stochastic algorithm on the'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'Stiefel manifold to solve problem '}, {'type': 'link', 'children': [{'type': 'text', 'raw': '['}, {'type': 'text', 'raw': 'p-1'}, {'type': 'text', 'raw': ']'}], 'attrs': {'url': '#p-1'}}, {'type': 'text', 'raw': '{reference-type="eqref"'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'reference="p-1"}. Each agent estimates its local gradient by'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'variable-sampled stochastic gradients, then obtains the search direction'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'based on the combination of multi-step consensus protocol and a gradient'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'tracking dynamic.'}], 'id': '1717748377-25'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-26'}),
#  Document(page_content='(2) Assuming that the sampled gradients are unbiased with bounded\nvariance and uniformly bounded on the Stiefel manifold. Suppose, in\naddition, that the local functions are L-smooth on Euclidean space and\nthe initial points of the agents belong to the local region defined in\nSection [4](#sec-4){reference-type="ref" reference="sec-4"}. The\niterates of all agents are proved to remain in an invariant subset on\nthe Stiefel manifold and eventually converge to a stationary point(or\nneighborhood) in expectation with fixed step sizes.\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '('}, {'type': 'text', 'raw': '2'}, {'type': 'text', 'raw': ')'}, {'type': 'text', 'raw': ' Assuming that the sampled gradients are unbiased with bounded'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'variance and uniformly bounded on the Stiefel manifold. Suppose, in'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'addition, that the local functions are L-smooth on Euclidean space and'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'the initial points of the agents belong to the local region defined in'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'Section '}, {'type': 'link', 'children': [{'type': 'text', 'raw': '4'}], 'attrs': {'url': '#sec-4'}}, {'type': 'text', 'raw': '{reference-type="ref" reference="sec-4"}. The'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'iterates of all agents are proved to remain in an invariant subset on'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'the Stiefel manifold and eventually converge to a stationary point(or'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'neighborhood) in expectation with fixed step sizes.'}], 'id': '1717748377-27'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-28'}),
#  Document(page_content='(3) We further show that the variable number of samples has an impact\non the convergence rate, since increasing sample size can reduce the\nnoise variance. When an exponentially increasing sample size is\nutilized, the convergence rate is proved to be $\\mathcal{O}(1/k)$, which\nis comparable to the deterministic framework. While for a constant\nsample size, the iterates converge to a neighborhood of the stationary\npoint with the rate $\\mathcal{O}(1/k)$. We further prove the convergence\nrate with polynomially increasing sample size as well. Besides, we\nestablish the iteration and oracle complexity, as well as the number of\ncommunications, to achieve an $\\epsilon$-stationary solution.\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '('}, {'type': 'text', 'raw': '3'}, {'type': 'text', 'raw': ')'}, {'type': 'text', 'raw': ' We further show that the variable number of samples has an impact'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'on the convergence rate, since increasing sample size can reduce the'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'noise variance. When an exponentially increasing sample size is'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'utilized, the convergence rate is proved to be $\\mathcal{O}(1/k)$, which'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'is comparable to the deterministic framework. While for a constant'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'sample size, the iterates converge to a neighborhood of the stationary'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'point with the rate $\\mathcal{O}(1/k)$. We further prove the convergence'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'rate with polynomially increasing sample size as well. Besides, we'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'establish the iteration and oracle complexity, as well as the number of'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'communications, to achieve an $\\epsilon$-stationary solution.'}], 'id': '1717748377-29'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-30'}),
#  Document(page_content='The paper is organized as follows. Section\n[2](#sec-2){reference-type="ref" reference="sec-2"} introduces some\npreliminaries of Riemannian geometry, the average on Stiefel manifold,\nand the optimality condition. We reformulate the distributed Riemannian\noptimization problem [[p-1]](#p-1){reference-type="eqref"\nreference="p-1"} and design the algorithm in Section\n[3](#sec-3){reference-type="ref" reference="sec-3"}, while the main\nresults are given in Section [4](#sec-4){reference-type="ref"\nreference="sec-4"}. Numerical experiments are provided in Section\n[5](#sec-5){reference-type="ref" reference="sec-5"}, while some\nconcluding remarks are given in Section [6](#sec-6){reference-type="ref"\nreference="sec-6"}.\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'The paper is organized as follows. Section'}, {'type': 'softbreak'}, {'type': 'link', 'children': [{'type': 'text', 'raw': '2'}], 'attrs': {'url': '#sec-2'}}, {'type': 'text', 'raw': '{reference-type="ref" reference="sec-2"} introduces some'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'preliminaries of Riemannian geometry, the average on Stiefel manifold,'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'and the optimality condition. We reformulate the distributed Riemannian'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'optimization problem '}, {'type': 'link', 'children': [{'type': 'text', 'raw': '['}, {'type': 'text', 'raw': 'p-1'}, {'type': 'text', 'raw': ']'}], 'attrs': {'url': '#p-1'}}, {'type': 'text', 'raw': '{reference-type="eqref"'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'reference="p-1"} and design the algorithm in Section'}, {'type': 'softbreak'}, {'type': 'link', 'children': [{'type': 'text', 'raw': '3'}], 'attrs': {'url': '#sec-3'}}, {'type': 'text', 'raw': '{reference-type="ref" reference="sec-3"}, while the main'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'results are given in Section '}, {'type': 'link', 'children': [{'type': 'text', 'raw': '4'}], 'attrs': {'url': '#sec-4'}}, {'type': 'text', 'raw': '{reference-type="ref"'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'reference="sec-4"}. Numerical experiments are provided in Section'}, {'type': 'softbreak'}, {'type': 'link', 'children': [{'type': 'text', 'raw': '5'}], 'attrs': {'url': '#sec-5'}}, {'type': 'text', 'raw': '{reference-type="ref" reference="sec-5"}, while some'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'concluding remarks are given in Section '}, {'type': 'link', 'children': [{'type': 'text', 'raw': '6'}], 'attrs': {'url': '#sec-6'}}, {'type': 'text', 'raw': '{reference-type="ref"'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'reference="sec-6"}.'}], 'id': '1717748377-31'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-32'}),
#  Document(page_content='**Notations.** Let $X^\\top$ denote the transposition of $X$ and\n$tr(\\cdot)$ denote the trace operator. Define the $N$-fold Cartesian\nproduct of $\\mathcal{M}$ as\n$\\mathcal{M}^N:=\\mathcal{M}\\times \\cdots \\times \\mathcal{M}$. Let $I_n$\ndenote the $n\\times n$ identity matrix and $\\bold{1}_N$ denote the\nN-dimensional vector with all ones, respectively. In addition, we\nsummarize the symbols used in this work in the following table (Table 1)\nfor ease of reference.\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'strong', 'children': [{'type': 'text', 'raw': 'Notations.'}]}, {'type': 'text', 'raw': ' Let $X^\\top$ denote the transposition of $X$ and'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$tr(\\cdot)$ denote the trace operator. Define the $N$-fold Cartesian'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'product of $\\mathcal{M}$ as'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$\\mathcal{M}^N:=\\mathcal{M}\\times \\cdots \\times \\mathcal{M}$. Let $I_n$'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'denote the $n\\times n$ identity matrix and $\\bold{1}'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'N$ denote the'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'N-dimensional vector with all ones, respectively. In addition, we'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'summarize the symbols used in this work in the following table (Table 1)'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'for ease of reference.'}], 'id': '1717748377-33'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-34'}),
#  Document(page_content='Symbol                                                         Notation\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'Symbol                                                         Notation'}], 'id': '1717748377-35'}),
#  Document(page_content='***\n\n', metadata={'type': 'thematic_break', 'id': '1717748377-36'}),
#  Document(page_content='$\\mathcal{M}$                                                  Riemannian manifold\n$T_X \\mathcal{M}, N_X \\mathcal{M}$                             tangent space and its orthogonal complement at $X$\n$\\nabla \\phi(X)$                                               Euclidean gradient\n$\\text{grad}\\ \\phi(X)$                                         Riemannian gradient\n$D\\phi(X)[v]$ ($v \\in T_X \\mathcal{M}$)                        the directional derivative along $v$\n$|\\cdot|*F$                                                  Frobenius norm\n$R_X(\\cdot)$                                                   retraction map\n$\\mathcal{R}_X(\\cdot)$                                         polar-retraction\n$\\mathcal{P}*{T_X \\mathcal{M}}$                                orthogonal projection onto the tangent space\n$\\bar X$and $\\bold{\\bar X}: = (\\bm{1}_N \\otimes I_n) \\bar X$   the Euclidean mean and its stacking matrix\n$\\hat X$and $\\bold{\\hat X}: = (\\bm{1}_N \\otimes I_n) \\hat X$   induced arithmetic mean and its stacking matrix\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '$\\mathcal{M}$                                                  Riemannian manifold'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$T_X \\mathcal{M}, N_X \\mathcal{M}$                             tangent space and its orthogonal complement at $X$'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$\\nabla \\phi(X)$                                               Euclidean gradient'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$\\text{grad}\\ \\phi(X)$                                         Riemannian gradient'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$D\\phi(X)'}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': 'v]$ ($v \\in T_X \\mathcal{M}$)                        the directional derivative along $v$'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '\\cdot'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F$                                                  Frobenius norm'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$R_X(\\cdot)$                                                   retraction map'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$\\mathcal{R}'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'X(\\cdot)$                                         polar-retraction'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$\\mathcal{P}'}]}, {'type': 'text', 'raw': '{T_X \\mathcal{M}}$                                orthogonal projection onto the tangent space'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$\\bar X$and $\\bold{\\bar X}: = (\\bm{1}'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'N \\otimes I_n) \\bar X$   the Euclidean mean and its stacking matrix'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$\\hat X$and $\\bold{\\hat X}: = (\\bm{1}'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'N \\otimes I_n) \\hat X$   induced arithmetic mean and its stacking matrix'}], 'id': '1717748377-37'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-38'}),
#  Document(page_content=': Symbol notations\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': ': Symbol notations'}], 'id': '1717748377-39'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-40'}),
#  Document(page_content='# Preliminaries {#sec-2}\n\n', metadata={'type': 'heading', 'attrs': {'level': 1}, 'style': 'axt', 'children': [{'type': 'text', 'raw': 'Preliminaries {#sec-2}'}], 'id': '1717748377-41'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-42'}),
#  Document(page_content='## Riemannian geometry {#sec-2.1}\n\n', metadata={'type': 'heading', 'attrs': {'level': 2}, 'style': 'axt', 'children': [{'type': 'text', 'raw': 'Riemannian geometry {#sec-2.1}'}], 'id': '1717748377-43'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-44'}),
#  Document(page_content='Before presenting the algorithm, we first introduce some basic concepts\nand geometric properties of the Riemannian manifold in this section. The\nreader can refer to literature [@AbsilMahonySepulchre+2008] for more\ninformation.\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'Before presenting the algorithm, we first introduce some basic concepts'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'and geometric properties of the Riemannian manifold in this section. The'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'reader can refer to literature '}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@AbsilMahonySepulchre+2008] for more'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'information.'}], 'id': '1717748377-45'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-46'}),
#  Document(page_content='A topological space is called a manifold if each of the point has a\nneighborhood that is diffeomorphism to $\\mathbb{R}^n$. If a smooth\nmanifold $\\mathcal{M}$ is equipped with a metric $\\mathfrak{g}$, then\n$(\\mathcal{M}, \\mathfrak{g})$ is called a Riemannian manifold. We focus\non the Stiefel manifold in this context, which is\n$\\text{St}(n,r):={X \\in \\mathbb{R}^{n \\times r}:X^\\top X = I_r}$.\n$\\text{St}(n,r)$ is compact and can be seen as the embedded submanifold\non the Euclidean space.\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'A topological space is called a manifold if each of the point has a'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'neighborhood that is diffeomorphism to $\\mathbb{R}^n$. If a smooth'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'manifold $\\mathcal{M}$ is equipped with a metric $\\mathfrak{g}$, then'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$(\\mathcal{M}, \\mathfrak{g})$ is called a Riemannian manifold. We focus'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'on the Stiefel manifold in this context, which is'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$\\text{St}(n,r):='}, {'type': 'text', 'raw': '{'}, {'type': 'text', 'raw': 'X \\in \\mathbb{R}^{n \\times r}:X^\\top X = I_r'}, {'type': 'text', 'raw': '}'}, {'type': 'text', 'raw': '$.'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$\\text{St}(n,r)$ is compact and can be seen as the embedded submanifold'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'on the Euclidean space.'}], 'id': '1717748377-47'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-48'}),
#  Document(page_content='We denote the tangent space at a point $X \\in \\text{St}(n,r)$ by\n$T_X\\mathcal{M}$, and its orthogonal complement with respect to the\nEuclidean space is denoted by the normal space $N_X\\mathcal{M}$.\nSpecifically, the tangent space of Stiefel manifold can be derived as\n$T_X\\mathcal{M}:={u \\in \\mathbb{R}^{n \\times r}: X^\\top u + u^\\top X = 0}$[@edelman1998geometry],\nwhich shows the tangent vectors are matrices. The metric on the tangent\nspace $T_X\\mathcal{M}$ is induced from the Euclidean inner product,\nwhich is\n$\\mathfrak{g}(u,v) :=\\langle u,v \\rangle = \\text{tr}( u^\\top v )$, where\n$u,v \\in T_X\\mathcal{M}$. Then the induced norm is equivalent to the\nFrobenius norm, i.e., $|u|_g = \\sqrt{\\text{tr}(u^\\top u) } = |u|_F$.\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'We denote the tangent space at a point $X \\in \\text{St}(n,r)$ by'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$T_X\\mathcal{M}$, and its orthogonal complement with respect to the'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'Euclidean space is denoted by the normal space $N_X\\mathcal{M}$.'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'Specifically, the tangent space of Stiefel manifold can be derived as'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$T_X\\mathcal{M}:='}, {'type': 'text', 'raw': '{'}, {'type': 'text', 'raw': 'u \\in \\mathbb{R}^{n \\times r}: X^\\top u + u^\\top X = 0'}, {'type': 'text', 'raw': '}'}, {'type': 'text', 'raw': '$'}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '@edelman1998geometry],'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'which shows the tangent vectors are matrices. The metric on the tangent'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'space $T_X\\mathcal{M}$ is induced from the Euclidean inner product,'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'which is'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$\\mathfrak{g}(u,v) :=\\langle u,v \\rangle = \\text{tr}( u^\\top v )$, where'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$u,v \\in T_X\\mathcal{M}$. Then the induced norm is equivalent to the'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'Frobenius norm, i.e., $'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'u'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'g = \\sqrt{\\text{tr}(u^\\top u) } = '}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'u'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'F$.'}], 'id': '1717748377-49'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-50'}),
#  Document(page_content='We then introduce the concept of exponential map to connect the tangent\nspace and manifold. An exponential map $\\text{Exp}*X$ maps a tangent\nvector $u$ to a point $Y: =  \\text{Exp}_X(u) \\in \\text{St}(n,r)$ such\nthat there exist a geodesic between $X, Y$ in the direction of\n$u \\in T_X \\mathcal{M}$, where geodesic is a curve that locally\nminimizes the length. However, the computation of an exponential map is\ncostly and has no closed form. The retraction $R_X$ is a first-order\napproximation of the exponential map with the requirement that 1)\n$R_X(0_X) = X$, where $0_X$ is the zero vector on $T_X\\mathcal{M}$; 2)\nthe differential of $R_X$ at $0_X$ is the identity map, i.e.,\n$D R_X (0_X) = id*{T_X \\mathcal{M}}$. For the Stiefel manifold, we\nchoose the polar retraction, which is defined as\n$$\\mathcal{R}_X(v) = (X+v)(I_r+v^\\top v)^{-1/2}.$$ For the polar\nretraction, we also have some nice properties summarized in the\nfollowing lemma.\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'We then introduce the concept of exponential map to connect the tangent'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'space and manifold. An exponential map $\\text{Exp}'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'X$ maps a tangent'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'vector $u$ to a point $Y: =  \\text{Exp}'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'X(u) \\in \\text{St}(n,r)$ such'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'that there exist a geodesic between $X, Y$ in the direction of'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$u \\in T_X \\mathcal{M}$, where geodesic is a curve that locally'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'minimizes the length. However, the computation of an exponential map is'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'costly and has no closed form. The retraction $R_X$ is a first-order'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'approximation of the exponential map with the requirement that 1)'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$R_X(0_X) = X$, where $0_X$ is the zero vector on $T_X\\mathcal{M}$; 2)'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'the differential of $R_X$ at $0_X$ is the identity map, i.e.,'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$D R_X (0_X) = id'}]}, {'type': 'text', 'raw': '{T_X \\mathcal{M}}$. For the Stiefel manifold, we'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'choose the polar retraction, which is defined as'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$$\\mathcal{R}'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'X(v) = (X+v)(I_r+v^\\top v)^{-1/2}.$$ For the polar'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'retraction, we also have some nice properties summarized in the'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'following lemma.'}], 'id': '1717748377-51'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-52'}),
# ...
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-321'}),
#  Document(page_content='\\end{aligned}$$ By the induction hypothesis that\n$|Y_{i,k} - \\bar F_{k-1}|*F \\leq 10A+L_G$, it follows that\n$$\\begin{aligned}\n\\label{2-5}\n&|Y*{i,k_0+1} - \\bar F_{k_0}|*F \\notag\\\n\\leq& \\sigma_2^t \\sqrt{N}(10A+L_G)+|\\text{grad}f(X*{i,k_0+1}) - \\text{grad}f(X_{i,k_0})|*F\\\n+&|F_i(X*{i,k_0+1}) - \\text{grad} f_i(X_{i,k_0+1})|*F+|F_i(X*{i,k_0}) - \\text{grad} f_i(X_{i,k_0})|_F.\\notag\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '\\end{aligned}$$ By the induction hypothesis that'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'Y_{i,k} - \\bar F_{k-1}'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F \\leq 10A+L_G$, it follows that'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$$\\begin{aligned}'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '\\label{2-5}'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '&'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'Y'}]}, {'type': 'text', 'raw': '{i,k_0+1} - \\bar F_{k_0}'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F \\notag'}, {'type': 'text', 'raw': '\\'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '\\leq& \\sigma_2^t \\sqrt{N}(10A+L_G)+'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '\\text{grad}f(X'}]}, {'type': 'text', 'raw': '{i,k_0+1}) - \\text{grad}f(X_{i,k_0})'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F'}, {'type': 'text', 'raw': '\\'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '+&'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'F_i(X'}]}, {'type': 'text', 'raw': '{i,k_0+1}) - \\text{grad} f_i(X_{i,k_0+1})'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F+'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'F_i(X'}]}, {'type': 'text', 'raw': '{i,k_0}) - \\text{grad} f_i(X_{i,k_0})'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'F.\\notag'}], 'id': '1717748377-322'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-323'}),
#  Document(page_content='\\end{aligned}$$\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': '\\end{aligned}$$'}], 'id': '1717748377-324'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-325'}),
#  Document(page_content='By recalling that\n$\\max_{X \\in \\text{St}(n,r)}|\\text{grad} f_i(X)|*F \\leq A$ stated in\nRemark [[re-4]](#re-4){reference-type="ref" reference="re-4"}, we\nderive $$\\label{2-6}\n|F_i(X_i) - \\text{grad} f_i(X_i)|_F \\leq |F_i(X_i) |_F+|\\text{grad} f_i(X_i)|_F\\leq 2A.$$\nThen by using Lemma [[al-4]](#al-4){reference-type="ref"\nreference="al-4"}, and substituting\n[[2-6]](#2-6){reference-type="eqref" reference="2-6"} into\n[[2-5]](#2-5){reference-type="eqref" reference="2-5"}, we further\nhave$$|Y*{i,k_0+1} - \\bar F_{k_0}|*F\\leq\\sigma_2^t \\sqrt{N}(10A+L_G)+L_G|X*{i,k_0+1} - X_{i,k_0}|*F+4A.$$Moreover,\nby using $\\sigma_2^t \\leq \\frac{1}{2\\sqrt{N}}$ since\n$t \\geq [\\log*{\\sigma_2}(\\frac{1}{2\\sqrt{N}})]$, we get $$\\label{2-3}\n|Y_{i,k_0+1} - \\bar F_{k_0}|*F\\leq\\frac{1}{2}(10A+L_G)+4A+L_G|X*{i,k_0+1} - X_{i,k_0}|_F.$$\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'By recalling that'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$\\max_{X \\in \\text{St}(n,r)}'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '\\text{grad} f_i(X)'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F \\leq A$ stated in'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'Remark '}, {'type': 'link', 'children': [{'type': 'text', 'raw': '['}, {'type': 'text', 'raw': 're-4'}, {'type': 'text', 'raw': ']'}], 'attrs': {'url': '#re-4'}}, {'type': 'text', 'raw': '{reference-type="ref" reference="re-4"}, we'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'derive $$\\label{2-6}'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'F_i(X_i) - \\text{grad} f_i(X_i)'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'F \\leq '}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'F_i(X_i) '}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'F+'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '\\text{grad} f_i(X_i)'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'F\\leq 2A.$$'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'Then by using Lemma '}, {'type': 'link', 'children': [{'type': 'text', 'raw': '['}, {'type': 'text', 'raw': 'al-4'}, {'type': 'text', 'raw': ']'}], 'attrs': {'url': '#al-4'}}, {'type': 'text', 'raw': '{reference-type="ref"'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'reference="al-4"}, and substituting'}, {'type': 'softbreak'}, {'type': 'link', 'children': [{'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '2-6'}, {'type': 'text', 'raw': ']'}], 'attrs': {'url': '#2-6'}}, {'type': 'text', 'raw': '{reference-type="eqref" reference="2-6"} into'}, {'type': 'softbreak'}, {'type': 'link', 'children': [{'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '2-5'}, {'type': 'text', 'raw': ']'}], 'attrs': {'url': '#2-5'}}, {'type': 'text', 'raw': '{reference-type="eqref" reference="2-5"}, we further'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'have$$'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'Y'}]}, {'type': 'text', 'raw': '{i,k_0+1} - \\bar F_{k_0}'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F\\leq\\sigma_2^t \\sqrt{N}(10A+L_G)+L_G'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'X'}]}, {'type': 'text', 'raw': '{i,k_0+1} - X_{i,k_0}'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F+4A.$$Moreover,'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'by using $\\sigma_2^t \\leq \\frac{1}{2\\sqrt{N}}$ since'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$t \\geq '}, {'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '\\log'}]}, {'type': 'text', 'raw': '{\\sigma_2}(\\frac{1}{2\\sqrt{N}})]$, we get $$\\label{2-3}'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'Y_{i,k_0+1} - \\bar F_{k_0}'}, {'type': 'text', 'raw': '| ...
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-327'}),
#  Document(page_content='For the last term of the right-hand side, the update of $X_{i,k+1}$ in\n[[re-u]](#re-u){reference-type="eqref" reference="re-u"} implies\n$$\\label{2-7}\n\\begin{aligned}\n|X_{i,k_0+1} - X_{i,k_0}|*F =&|\\mathcal{R}*{X_{i,k_0}}(-\\alpha \\text{grad}\\ h_{i,t}(\\bold{X}*{k_0})-\\beta v*{i,k_0}) - X_{i,k_0}|*F\\\n\\leq& \\alpha |\\text{grad} h*{i,t}(\\bold{X}*{k_0})|_F+\\beta |Y*{i,k_0}|*F.\n\\end{aligned}$$ where the inequality follows by Lemma\n[[lem-1]](#lem-1){reference-type="ref" reference="lem-1"} and\n$|v*{i,k_0}|*F \\leq |Y*{i,k_0}|_F$.\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'For the last term of the right-hand side, the update of $X_{i,k+1}$ in'}, {'type': 'softbreak'}, {'type': 'link', 'children': [{'type': 'text', 'raw': '['}, {'type': 'text', 'raw': 're-u'}, {'type': 'text', 'raw': ']'}], 'attrs': {'url': '#re-u'}}, {'type': 'text', 'raw': '{reference-type="eqref" reference="re-u"} implies'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$$\\label{2-7}'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '\\begin{aligned}'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'X_{i,k_0+1} - X_{i,k_0}'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F =&'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '\\mathcal{R}'}]}, {'type': 'text', 'raw': '{X_{i,k_0}}(-\\alpha \\text{grad}\\ h_{i,t}(\\bold{X}'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': '{k_0})-\\beta v'}]}, {'type': 'text', 'raw': '{i,k_0}) - X_{i,k_0}'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F'}, {'type': 'text', 'raw': '\\'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '\\leq& \\alpha '}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '\\text{grad} h'}]}, {'type': 'text', 'raw': '{i,t}(\\bold{X}'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': '{k_0})'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'F+\\beta '}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'Y'}]}, {'type': 'text', 'raw': '{i,k_0}'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F.'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '\\end{aligned}$$ where the inequality follows by Lemma'}, {'type': 'softbreak'}, {'type': 'link', 'children': [{'type': 'text', 'raw': '['}, {'type': 'text', 'raw': 'lem-1'}, {'type': 'text', 'raw': ']'}], 'attrs': {'url': '#lem-1'}}, {'type': 'text', 'raw': '{reference-type="ref" reference="lem-1"} and'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'v'}]}, {'type': 'text', 'raw': '{i,k_0}'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F \\leq '}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'Y'}]}, {'type': 'text', 'raw': '{i,k_0}'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'F$.'}], 'id': '1717748377-328'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-329'}),
#  Document(page_content='Since $\\bold{X}*{k_0+1} \\in \\mathcal{S}$, the term\n$|\\text{grad} h*{i,t}(\\bold{X}*{k_0})|_F$ is bounded by Lemma\n[[al-3]](#al-3){reference-type="ref" reference="al-3"}, which implies\n$\\alpha|\\text{grad} h*{i,t}(\\bold{X}*{k_0})|_F \\leq 2\\delta_2 \\alpha.$\nAs $\\beta \\leq\\frac{\\alpha \\delta_1}{5(10A+L_G)}$, and by using the\ninduction hypothesis that $|Y*{i,k}|*F \\leq 10A+L_G$, we have\n$\\beta|Y*{i,k_0}|*F \\leq \\frac{1}{5}\\delta_1 \\alpha.$ Substituting\nthese results into [[2-7]](#2-7){reference-type="eqref"\nreference="2-7"} implies that\n$$|X*{i,k_0+1} - X_{i,k_0}|*F \\leq 2\\delta_2 \\alpha+ \\frac{1}{5}\\delta_1 \\alpha.$$\nThis together with [[2-3]](#2-3){reference-type="eqref"\nreference="2-3"} implies\n$$|Y*{i,k_0+1} - \\bar F_{k_0}|_F\\leq 9A+\\frac{1}{2}L_G+ 2\\delta_2 L_G +\\frac{L_G}{5}\\delta_1 \\alpha \\leq 9A+L_G.$$\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'Since $\\bold{X}'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': '{k_0+1} \\in \\mathcal{S}$, the term'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '\\text{grad} h'}]}, {'type': 'text', 'raw': '{i,t}(\\bold{X}'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': '{k_0})'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'F$ is bounded by Lemma'}, {'type': 'softbreak'}, {'type': 'link', 'children': [{'type': 'text', 'raw': '['}, {'type': 'text', 'raw': 'al-3'}, {'type': 'text', 'raw': ']'}], 'attrs': {'url': '#al-3'}}, {'type': 'text', 'raw': '{reference-type="ref" reference="al-3"}, which implies'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$\\alpha'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '\\text{grad} h'}]}, {'type': 'text', 'raw': '{i,t}(\\bold{X}'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': '{k_0})'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'F \\leq 2\\delta_2 \\alpha.$'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'As $\\beta \\leq\\frac{\\alpha \\delta_1}{5(10A+L_G)}$, and by using the'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'induction hypothesis that $'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'Y'}]}, {'type': 'text', 'raw': '{i,k}'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F \\leq 10A+L_G$, we have'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$\\beta'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'Y'}]}, {'type': 'text', 'raw': '{i,k_0}'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F \\leq \\frac{1}{5}\\delta_1 \\alpha.$ Substituting'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'these results into '}, {'type': 'link', 'children': [{'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '2-7'}, {'type': 'text', 'raw': ']'}], 'attrs': {'url': '#2-7'}}, {'type': 'text', 'raw': '{reference-type="eqref"'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'reference="2-7"} implies that'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$$'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'X'}]}, {'type': 'text', 'raw': '{i,k_0+1} - X_{i,k_0}'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F \\leq 2\\delta_2 \\alpha+ \\frac{1}{5}\\delta_1 \\alpha.$$'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'This together with '}, {'type': 'link', 'children': [{'type': 'text', 'raw': '['}, {'type': 'text', 'raw': '2-3'}, {'type': 'text', 'raw': ']'}], 'attrs': {'url': '#2-3'}}, {'type': 'text', 'raw': '{reference-type="eqref"'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'reference="2-3"} implies'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$$'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'Y'}]}, {'type': 'text', 'raw': '{i,k_0+1} - \\bar F_{k_0}'}, {'type': 'text', 'raw': '|'}, {' ...
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-331'}),
#  Document(page_content='According to Assumption [[assu-3]](#assu-3){reference-type="ref"\nreference="assu-3"}, we have $|\\bar F_k|*F \\leq A, \\forall k \\geq 0$,\nwhich yields\n$$|Y*{i,k_0+1}|*F \\leq |Y*{i,k_0+1} - \\bar F_{k_0}|*F+|\\bar F*{k_0}|_F \\leq 10A+L_G.$$\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'According to Assumption '}, {'type': 'link', 'children': [{'type': 'text', 'raw': '['}, {'type': 'text', 'raw': 'assu-3'}, {'type': 'text', 'raw': ']'}], 'attrs': {'url': '#assu-3'}}, {'type': 'text', 'raw': '{reference-type="ref"'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'reference="assu-3"}, we have $'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '\\bar F_k'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F \\leq A, \\forall k \\geq 0$,'}, {'type': 'softbreak'}, {'type': 'text', 'raw': 'which yields'}, {'type': 'softbreak'}, {'type': 'text', 'raw': '$$'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'Y'}]}, {'type': 'text', 'raw': '{i,k_0+1}'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F \\leq '}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': 'Y'}]}, {'type': 'text', 'raw': '{i,k_0+1} - \\bar F_{k_0}'}, {'type': 'text', 'raw': '|'}, {'type': 'emphasis', 'children': [{'type': 'text', 'raw': 'F+'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '\\bar F'}]}, {'type': 'text', 'raw': '{k_0}'}, {'type': 'text', 'raw': '|'}, {'type': 'text', 'raw': '_'}, {'type': 'text', 'raw': 'F \\leq 10A+L_G.$$'}], 'id': '1717748377-332'}),
#  Document(page_content='', metadata={'type': 'blank_line', 'id': '1717748377-333'}),
#  Document(page_content='Therefore, the proof is completed.\n\n', metadata={'type': 'paragraph', 'children': [{'type': 'text', 'raw': 'Therefore, the proof is completed.'}], 'id': '1717748377-334'})]
